# %% [markdown]
# <a href="https://colab.research.google.com/github/rokugatsu/HomeCreditDefaultRisk/blob/main/My_competition2_v10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Home Credit Default Risk
# このnotebookでは、予測結果を作成するまでの流れと基本的な手法についての紹介を行います。
#
#
# まずは、今回のタスクについて確認しましょう（詳細はREADME.ipynbをご覧ください）。
# - **目的**： 顧客データから債務不履行になる確率を予測する。
# - **評価指標**： AUC（Area Under the Curve）
#
# Omni: 0.74053

# %% [markdown]
# ## 目次
# 0. ライブラリ・データの読み込み
# 1. データの可視化と分析
# 2. 前処理と特徴量作成
# 3. 機械学習モデルの作成
# 4. 予測結果の作成

# %% [markdown]
# ## 0. ライブラリ・データの読み込み

# %% [markdown]
# 基本的なライブラリを読み込みます。
# 他の必要なライブラリについては、説明をする際に読み込みます。
# - numpy：数値計算を効率的に行うライブラリ
# - pandas：データ分析に便利なライブラリ
# - matplotlib：グラフ描画ライブラリ
# - seaborn：グラフ描画ライブラリ

# %%
#pip install sweetviz

# %%
#import sweetviz as sv

# %%
# ライブラリの読み込み
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# 必要なデータの読み込みを行います。GCIの教材フォルダの構成を想定して、読み込んでいます。

# %%
# Google Colaboratoryで作業する場合はこちらも実行してください。
from google.colab import drive
drive.mount('/content/drive')
# %cd 以降にこのnotebookを置いているディレクトリを指定してください。
#%cd "/content/drive/MyDrive"
# %cd "/content/drive/MyDrive/data/competition2"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/data/competition2

# %%
#Switch Kaggle or Omini
key_kaggle = True

# %%
# データの読み込み
# INPUT_DIRにtrain.csvなどのデータを置いているディレクトリを指定してください。
INPUT_DIR = "./input/"

if key_kaggle == True:
  #For kaggle
  train = pd.read_csv(INPUT_DIR + "application_train.csv")
  test  = pd.read_csv(INPUT_DIR + "application_test.csv")
  sample_sub = pd.read_csv(INPUT_DIR + "sample_submission_kaggle.csv")
else:
  #For Omni
  train = pd.read_csv(INPUT_DIR + "train.csv")
  test = pd.read_csv(INPUT_DIR + "test.csv")
  sample_sub = pd.read_csv(INPUT_DIR + "sample_submission.csv")

#sample_sub

# %% [markdown]
# ## 1. データの可視化と分析

# %% [markdown]
# ### 1.1 データの概観
# 本格的な分析を行う前に、まずは簡単にデータの概観を確認します。

# %%
# trainデータの確認
print(f"train shape: {train.shape}")
#train.head(3)
train.head(10)
# Out:
# train shape: (171202, 51)
#    SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 0           0       0         Cash loans           F            N
# 1           1       0         Cash loans           F            N
# 2           2       0         Cash loans           F            N
# 3           3       0         Cash loans           F            N
# 4           4       1         Cash loans           M            N
# 5           5       1         Cash loans           F            N
# 6           6       0         Cash loans           F            N
# 7           7       1         Cash loans           M            N
# 8           8       0         Cash loans           M            Y
# 9           9       1         Cash loans           F            N
#
#   FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# 0               N             0          112500.0    755190.0      36328.5
# 1               Y             0          225000.0    585000.0      16893.0
# 2               Y             0           54000.0    334152.0      18256.5
# 3               Y             0           67500.0    152820.0       8901.0
# 4               N             0          157500.0    271066.5      21546.0
# 5               Y             0          135000.0    247500.0      19971.0
# 6               Y             0          189000.0    332946.0      17127.0
# 7               Y             0          157500.0    203760.0      24309.0
# 8               N             1          324000.0    808650.0      22234.5
# 9               Y             1          180000.0    207117.0      16492.5
#
#    ...  EXT_SOURCE_3 OBS_30_CNT_SOCIAL_CIRCLE DEF_30_CNT_SOCIAL_CIRCLE  \
# 0  ...           NaN                      0.0                      0.0
# 1  ...      0.553165                      0.0                      0.0
# 2  ...           NaN                      4.0                      0.0
# 3  ...      0.767523                      0.0                      0.0
# 4  ...      0.669057                      0.0                      0.0
# 5  ...           NaN                      0.0                      0.0
# 6  ...      0.399676                      6.0                      0.0
# 7  ...           NaN                      0.0                      0.0
# 8  ...      0.629674                      1.0                      0.0
# 9  ...           NaN                      1.0                      0.0
#
#   OBS_60_CNT_SOCIAL_CIRCLE DEF_60_CNT_SOCIAL_CIRCLE DAYS_LAST_PHONE_CHANGE  \
# 0                      0.0                      0.0                 -292.0
# 1                      0.0                      0.0                 -617.0
# 2                      4.0                      0.0                 -542.0
# 3                      0.0                      0.0                    0.0
# 4                      0.0                      0.0                -1243.0
# 5                      0.0                      0.0                 -307.0
# 6                      6.0                      0.0                -1918.0
# 7                      0.0                      0.0                    0.0
# 8                      1.0                      0.0                   -1.0
# 9                      1.0                      0.0                 -905.0
#
#    AMT_REQ_CREDIT_BUREAU_HOUR  AMT_REQ_CREDIT_BUREAU_MON  \
# 0                         NaN                        NaN
# 1                         0.0                        0.0
# 2                         NaN                        NaN
# 3                         0.0                        0.0
# 4                         0.0                        0.0
# 5                         NaN                        NaN
# 6                         0.0                        0.0
# 7                         NaN                        NaN
# 8                         0.0                        0.0
# 9                         NaN                        NaN
#
#    AMT_REQ_CREDIT_BUREAU_QRT  AMT_REQ_CREDIT_BUREAU_YEAR
# 0                        NaN                         NaN
# 1                        0.0                         1.0
# 2                        NaN                         NaN
# 3                        0.0                         0.0
# 4                        0.0                         4.0
# 5                        NaN                         NaN
# 6                        0.0                         3.0
# 7                        NaN                         NaN
# 8                        0.0                         0.0
# 9                        NaN                         NaN
#
# [10 rows x 51 columns]

# %%
# testデータの確認
print(f"test shape: {test.shape}")
#train.head(3)
test.head(10)
# Out:
# test shape: (61500, 50)
#    SK_ID_CURR NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  \
# 0      171202         Cash loans           F            N               N
# 1      171203         Cash loans           F            N               N
# 2      171204         Cash loans           F            N               Y
# 3      171205    Revolving loans           F            N               Y
# 4      171206         Cash loans           F            Y               Y
# 5      171207         Cash loans           M            N               Y
# 6      171208         Cash loans           M            Y               Y
# 7      171209         Cash loans           F          NaN             NaN
# 8      171210         Cash loans           M            N               Y
# 9      171211         Cash loans           F            Y               N
#
#    CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  AMT_GOODS_PRICE  \
# 0             1          144000.0    961146.0      28233.0         688500.0
# 1             0          103500.0    296280.0      16069.5         225000.0
# 2             1          180000.0    183694.5      11236.5         139500.0
# 3             2          225000.0    450000.0      22500.0         450000.0
# 4             2          144000.0    545040.0      26640.0         450000.0
# 5             0          274590.0   2115000.0      55791.0        2115000.0
# 6             0          202500.0    560664.0      18216.0         468000.0
# 7             0           90000.0    225000.0      22252.5         225000.0
# 8             1          225000.0    675000.0      43267.5         675000.0
# 9             0          180000.0    431280.0      22149.0         360000.0
#
#    ... EXT_SOURCE_3 OBS_30_CNT_SOCIAL_CIRCLE DEF_30_CNT_SOCIAL_CIRCLE  \
# 0  ...          NaN                      2.0                      0.0
# 1  ...          NaN                      5.0                      0.0
# 2  ...     0.389339                      7.0                      0.0
# 3  ...     0.217629                      2.0                      0.0
# 4  ...          NaN                      2.0                      0.0
# 5  ...     0.304672                      0.0                      0.0
# 6  ...          NaN                      1.0                      0.0
# 7  ...          NaN                      1.0                      0.0
# 8  ...     0.450747                      0.0                      0.0
# 9  ...     0.336062                      0.0                      0.0
#
#   OBS_60_CNT_SOCIAL_CIRCLE DEF_60_CNT_SOCIAL_CIRCLE  DAYS_LAST_PHONE_CHANGE  \
# 0                      2.0                      0.0                    -1.0
# 1                      5.0                      0.0                  -212.0
# 2                      7.0                      0.0                  -428.0
# 3                      2.0                      0.0                  -442.0
# 4                      2.0                      0.0                 -1333.0
# 5                      0.0                      0.0                    -1.0
# 6                      1.0                      0.0                 -2169.0
# 7                      1.0                      0.0                 -1761.0
# 8                      0.0                      0.0                  -108.0
# 9                      0.0                      0.0                 -2729.0
#
#    AMT_REQ_CREDIT_BUREAU_HOUR  AMT_REQ_CREDIT_BUREAU_MON  \
# 0                         NaN                        NaN
# 1                         NaN                        NaN
# 2                         0.0                        1.0
# 3                         0.0                        0.0
# 4                         0.0                        0.0
# 5                         0.0                        0.0
# 6                         NaN                        NaN
# 7                         NaN                        NaN
# 8                         0.0                        0.0
# 9                         0.0                        0.0
#
#    AMT_REQ_CREDIT_BUREAU_QRT  AMT_REQ_CREDIT_BUREAU_YEAR
# 0                        NaN                         NaN
# 1                        NaN                         NaN
# 2                        1.0                         1.0
# 3                        0.0                         3.0
# 4                        0.0                         3.0
# 5                        0.0                         0.0
# 6                        NaN                         NaN
# 7                        NaN                         NaN
# 8                        0.0                         4.0
# 9                        1.0                         7.0
#
# [10 rows x 50 columns]

# %% [markdown]
# 特徴量が50種類もあることが分かります。このnotebookでは、50種類全ての特徴量について分析することはせず、5種類の特徴量に絞って分析を行います。今回のように特徴量が多い場合は、初めから全ての特徴量に対して、分析や前処理を行うのは大変だと思います。なので、初めは少ない特徴量で予測結果を出すことを目標に取り組んでみて、それから扱う特徴量を増やしてみると取り組みやすいです。残りの45種類の特徴量については、今までの教材やこのnotebook等を参考にして、自分の力で分析を行ってみてください。
#
#
# 使用する5種類の特徴量については、様々な処理の説明を行えるように選択しています。

# %%
test.columns
# Out:
# Index(['SK_ID_CURR', 'NAME_CONTRACT_TYPE', 'CODE_GENDER', 'FLAG_OWN_CAR',
#        'FLAG_OWN_REALTY', 'CNT_CHILDREN', 'AMT_INCOME_TOTAL', 'AMT_CREDIT',
#        'AMT_ANNUITY', 'AMT_GOODS_PRICE', 'NAME_TYPE_SUITE', 'NAME_INCOME_TYPE',
#        'NAME_EDUCATION_TYPE', 'NAME_FAMILY_STATUS', 'NAME_HOUSING_TYPE',
#        'REGION_POPULATION_RELATIVE', 'DAYS_BIRTH', 'DAYS_EMPLOYED',
#        'DAYS_REGISTRATION', 'DAYS_ID_PUBLISH', 'OWN_CAR_AGE', 'FLAG_MOBIL',
#        'FLAG_EMP_PHONE', 'FLAG_WORK_PHONE', 'FLAG_CONT_MOBILE', 'FLAG_PHONE',
#        'FLAG_EMAIL', 'OCCUPATION_TYPE', 'CNT_FAM_MEMBERS',
#        'REGION_RATING_CLIENT', 'REGION_RATING_CLIENT_W_CITY',
#        'REG_REGION_NOT_LIVE_REGION', 'REG_REGION_NOT_WORK_REGION',
#        'LIVE_REGION_NOT_WORK_REGION', 'REG_CITY_NOT_LIVE_CITY',
#        'REG_CITY_NOT_WORK_CITY', 'LIVE_CITY_NOT_WORK_CITY',
#        'ORGANIZATION_TYPE', 'EXT_SOURCE_1', 'EXT_SOURCE_2', 'EXT_SOURCE_3',
#        'OBS_30_CNT_SOCIAL_CIRCLE', 'DEF_30_CNT_SOCIAL_CIRCLE',
#        'OBS_60_CNT_SOCIAL_CIRCLE', 'DEF_60_CNT_SOCIAL_CIRCLE',
#        'DAYS_LAST_PHONE_CHANGE', 'AMT_REQ_CREDIT_BUREAU_HOUR',
#        'AMT_REQ_CREDIT_BUREAU_MON', 'AMT_REQ_CREDIT_BUREAU_QRT',
#        'AMT_REQ_CREDIT_BUREAU_YEAR'],
#       dtype='object')

# %% [markdown]
# sweetviz

# %%
#report = sv.analyze(train, target_feat="TARGET")

# %%
#report.show_notebook()

# %%
#report.show_html("eda.html")

# %%
# 5種類の特徴量に絞る
#use_features = ["NAME_CONTRACT_TYPE", "AMT_INCOME_TOTAL", "EXT_SOURCE_2", "OWN_CAR_AGE", "ORGANIZATION_TYPE"]
#target = train["TARGET"].values
#train = train[use_features]
#train["TARGET"] = target
#test = test[use_features]

# %%
# 5種類の特徴量に絞る
#use_features = ["NAME_CONTRACT_TYPE", "AMT_INCOME_TOTAL", "OWN_CAR_AGE", "ORGANIZATION_TYPE","CNT_FAM_MEMBERS","NAME_TYPE_SUITE","NAME_INCOME_TYPE","NAME_EDUCATION_TYPE"]
#use_features = ["NAME_CONTRACT_TYPE", "AMT_INCOME_TOTAL", "OWN_CAR_AGE", "ORGANIZATION_TYPE","CNT_FAM_MEMBERS","NAME_INCOME_TYPE","NAME_EDUCATION_TYPE","NAME_HOUSING_TYPE"]
#use_features = ["NAME_CONTRACT_TYPE", "AMT_INCOME_TOTAL", "OWN_CAR_AGE", "ORGANIZATION_TYPE","CNT_FAM_MEMBERS","NAME_INCOME_TYPE","NAME_EDUCATION_TYPE"]
#use_features = ["NAME_CONTRACT_TYPE", "AMT_INCOME_TOTAL", "OWN_CAR_AGE", "ORGANIZATION_TYPE","CNT_FAM_MEMBERS","NAME_INCOME_TYPE","OCCUPATION_TYPE"]
#use_features = ["NAME_CONTRACT_TYPE","NAME_INCOME_TYPE","AMT_INCOME_TOTAL", "OWN_CAR_AGE", "ORGANIZATION_TYPE","OCCUPATION_TYPE","REGION_RATING_CLIENT","REGION_RATING_CLIENT_W_CITY"]
use_features = ["NAME_CONTRACT_TYPE","NAME_INCOME_TYPE","AMT_INCOME_TOTAL", "OWN_CAR_AGE", "ORGANIZATION_TYPE","OCCUPATION_TYPE"]

target = train["TARGET"].values
train_ft = train[use_features]
train_ft["TARGET"] = target
test_ft = test[use_features]

# %% [markdown]
# 再度、データの確認を行います。

# %%
# trainデータの確認
print(f"train shape: {train.shape}")
train_ft.head(10)
# Out:
# train shape: (171202, 51)
#   NAME_CONTRACT_TYPE      NAME_INCOME_TYPE  AMT_INCOME_TOTAL  OWN_CAR_AGE  \
# 0         Cash loans               Working          112500.0          NaN
# 1         Cash loans             Pensioner          225000.0          NaN
# 2         Cash loans         State servant           54000.0          NaN
# 3         Cash loans             Pensioner           67500.0          NaN
# 4         Cash loans  Commercial associate          157500.0          NaN
# 5         Cash loans  Commercial associate          135000.0          NaN
# 6         Cash loans  Commercial associate          189000.0          NaN
# 7         Cash loans               Working          157500.0          NaN
# 8         Cash loans         State servant          324000.0          1.0
# 9         Cash loans               Working          180000.0          NaN
#
#         ORGANIZATION_TYPE OCCUPATION_TYPE  TARGET
# 0                  School      Core staff       0
# 1                     XNA             NaN       0
# 2                  Postal      Core staff       0
# 3                     XNA             NaN       0
# 4  Business Entity Type 3         Drivers       1
# 5       Transport: type 4  Cleaning staff       1
# 6           Trade: type 3   Cooking staff       0
# 7  Business Entity Type 3             NaN       1
# 8                Military        Managers       0
# 9           Self-employed     Sales staff       1

# %%
# testデータの確認
print(f"test shape: {test.shape}")
test.head(3)
# Out:
# test shape: (61500, 50)
#    SK_ID_CURR NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  \
# 0      171202         Cash loans           F            N               N
# 1      171203         Cash loans           F            N               N
# 2      171204         Cash loans           F            N               Y
#
#    CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  AMT_GOODS_PRICE  \
# 0             1          144000.0    961146.0      28233.0         688500.0
# 1             0          103500.0    296280.0      16069.5         225000.0
# 2             1          180000.0    183694.5      11236.5         139500.0
#
#    ... EXT_SOURCE_3 OBS_30_CNT_SOCIAL_CIRCLE DEF_30_CNT_SOCIAL_CIRCLE  \
# 0  ...          NaN                      2.0                      0.0
# 1  ...          NaN                      5.0                      0.0
# 2  ...     0.389339                      7.0                      0.0
#
#   OBS_60_CNT_SOCIAL_CIRCLE DEF_60_CNT_SOCIAL_CIRCLE  DAYS_LAST_PHONE_CHANGE  \
# 0                      2.0                      0.0                    -1.0
# 1                      5.0                      0.0                  -212.0
# 2                      7.0                      0.0                  -428.0
#
#    AMT_REQ_CREDIT_BUREAU_HOUR  AMT_REQ_CREDIT_BUREAU_MON  \
# 0                         NaN                        NaN
# 1                         NaN                        NaN
# 2                         0.0                        1.0
#
#    AMT_REQ_CREDIT_BUREAU_QRT  AMT_REQ_CREDIT_BUREAU_YEAR
# 0                        NaN                         NaN
# 1                        NaN                         NaN
# 2                        1.0                         1.0
#
# [3 rows x 50 columns]

# %% [markdown]
# ### 1.2 データの可視化・分析(EDA)
# データを可視化して分析を行います。この作業では、特徴量の値の分布, 欠損値, 外れ値, 相関関係などの確認を行うことでデータへの理解を深めます。この段階で得られる分析結果を元に、前処理、特徴量の作成、機械学習モデルの選択などを行うので、最終的な予測に大きく影響する重要な作業となります。Kaggle上でも様々な方がEDAを行ったコードが公開されているので、参考にしてみると良いです。

# %% [markdown]
# #### 1.2.1 欠損値の確認
# ここでは、欠損値の確認を行います。
# ほとんどの機械学習モデルでは、欠損値があるデータで学習を行うことができません。そのため、何かしらの値で欠損値を埋める必要があるので、欠損値の確認を必ず行います。

# %% [markdown]
# #Examine Missing Values
#
# Next we can look at the number and percentage of missing values in each column.

# %%
# Function to calculate missing values by column# Funct
def missing_values_table(df):
        # Total missing values
        mis_val = df.isnull().sum()

        # Percentage of missing values
        mis_val_percent = 100 * df.isnull().sum() / len(df)

        # Make a table with the results
        mis_val_table = pd.concat([mis_val, mis_val_percent], axis=1)

        # Rename the columns
        mis_val_table_ren_columns = mis_val_table.rename(
        columns = {0 : 'Missing Values', 1 : '% of Total Values'})

        # Sort the table by percentage of missing descending
        mis_val_table_ren_columns = mis_val_table_ren_columns[
            mis_val_table_ren_columns.iloc[:,1] != 0].sort_values(
        '% of Total Values', ascending=False).round(1)

        # Print some summary information
        print ("Your selected dataframe has " + str(df.shape[1]) + " columns.\n"
            "There are " + str(mis_val_table_ren_columns.shape[0]) +
              " columns that have missing values.")

        # Return the dataframe with missing information
        return mis_val_table_ren_columns

# %%
# Missing values statistics
missing_values = missing_values_table(train)
missing_values.head(20)
# Out:
# Your selected dataframe has 51 columns.
# There are 20 columns that have missing values.
#                             Missing Values  % of Total Values
# EXT_SOURCE_1                        118928               69.5
# OWN_CAR_AGE                         112992               66.0
# EXT_SOURCE_3                         54586               31.9
# OCCUPATION_TYPE                      53745               31.4
# FLAG_OWN_REALTY                      34241               20.0
# FLAG_OWN_CAR                         34241               20.0
# AMT_REQ_CREDIT_BUREAU_HOUR           23116               13.5
# AMT_REQ_CREDIT_BUREAU_MON            23116               13.5
# AMT_REQ_CREDIT_BUREAU_QRT            23116               13.5
# AMT_REQ_CREDIT_BUREAU_YEAR           23116               13.5
# NAME_TYPE_SUITE                        747                0.4
# OBS_30_CNT_SOCIAL_CIRCLE               560                0.3
# DEF_30_CNT_SOCIAL_CIRCLE               560                0.3
# OBS_60_CNT_SOCIAL_CIRCLE               560                0.3
# DEF_60_CNT_SOCIAL_CIRCLE               560                0.3
# EXT_SOURCE_2                           369                0.2
# AMT_GOODS_PRICE                        163                0.1
# AMT_ANNUITY                              6                0.0
# CNT_FAM_MEMBERS                          2                0.0
# DAYS_LAST_PHONE_CHANGE                   1                0.0

# %%
train.dtypes.value_counts()
# Out:
# int64      20
# float64    20
# object     11
# Name: count, dtype: int64

# %%
# Number of unique classes in each object column
train.select_dtypes('object').apply(pd.Series.nunique, axis = 0)
# Out:
# NAME_CONTRACT_TYPE      2
# CODE_GENDER             3
# FLAG_OWN_CAR            2
# FLAG_OWN_REALTY         2
# NAME_TYPE_SUITE         7
# NAME_INCOME_TYPE        8
# NAME_EDUCATION_TYPE     5
# NAME_FAMILY_STATUS      6
# NAME_HOUSING_TYPE       6
# OCCUPATION_TYPE        18
# ORGANIZATION_TYPE      58
# dtype: int64

# %%
# trainの欠損値を確認
train.isnull().sum()
# Out:
# SK_ID_CURR                          0
# TARGET                              0
# NAME_CONTRACT_TYPE                  0
# CODE_GENDER                         0
# FLAG_OWN_CAR                    34241
# FLAG_OWN_REALTY                 34241
# CNT_CHILDREN                        0
# AMT_INCOME_TOTAL                    0
# AMT_CREDIT                          0
# AMT_ANNUITY                         6
# AMT_GOODS_PRICE                   163
# NAME_TYPE_SUITE                   747
# NAME_INCOME_TYPE                    0
# NAME_EDUCATION_TYPE                 0
# NAME_FAMILY_STATUS                  0
# NAME_HOUSING_TYPE                   0
# REGION_POPULATION_RELATIVE          0
# DAYS_BIRTH                          0
# DAYS_EMPLOYED                       0
# DAYS_REGISTRATION                   0
# DAYS_ID_PUBLISH                     0
# OWN_CAR_AGE                    112992
# FLAG_MOBIL                          0
# FLAG_EMP_PHONE                      0
# FLAG_WORK_PHONE                     0
# FLAG_CONT_MOBILE                    0
# FLAG_PHONE                          0
# FLAG_EMAIL                          0
# OCCUPATION_TYPE                 53745
# CNT_FAM_MEMBERS                     2
# REGION_RATING_CLIENT                0
# REGION_RATING_CLIENT_W_CITY         0
# REG_REGION_NOT_LIVE_REGION          0
# REG_REGION_NOT_WORK_REGION          0
# LIVE_REGION_NOT_WORK_REGION         0
# REG_CITY_NOT_LIVE_CITY              0
# REG_CITY_NOT_WORK_CITY              0
# LIVE_CITY_NOT_WORK_CITY             0
# ORGANIZATION_TYPE                   0
# EXT_SOURCE_1                   118928
# EXT_SOURCE_2                      369
# EXT_SOURCE_3                    54586
# OBS_30_CNT_SOCIAL_CIRCLE          560
# DEF_30_CNT_SOCIAL_CIRCLE          560
# OBS_60_CNT_SOCIAL_CIRCLE          560
# DEF_60_CNT_SOCIAL_CIRCLE          560
# DAYS_LAST_PHONE_CHANGE              1
# AMT_REQ_CREDIT_BUREAU_HOUR      23116
# AMT_REQ_CREDIT_BUREAU_MON       23116
# AMT_REQ_CREDIT_BUREAU_QRT       23116
# AMT_REQ_CREDIT_BUREAU_YEAR      23116
# dtype: int64

# %%
# testの欠損値を確認
test.isnull().sum()
# Out:
# SK_ID_CURR                         0
# NAME_CONTRACT_TYPE                 0
# CODE_GENDER                        0
# FLAG_OWN_CAR                   12334
# FLAG_OWN_REALTY                12334
# CNT_CHILDREN                       0
# AMT_INCOME_TOTAL                   0
# AMT_CREDIT                         0
# AMT_ANNUITY                        3
# AMT_GOODS_PRICE                   53
# NAME_TYPE_SUITE                  248
# NAME_INCOME_TYPE                   0
# NAME_EDUCATION_TYPE                0
# NAME_FAMILY_STATUS                 0
# NAME_HOUSING_TYPE                  0
# REGION_POPULATION_RELATIVE         0
# DAYS_BIRTH                         0
# DAYS_EMPLOYED                      0
# DAYS_REGISTRATION                  0
# DAYS_ID_PUBLISH                    0
# OWN_CAR_AGE                    40909
# FLAG_MOBIL                         0
# FLAG_EMP_PHONE                     0
# FLAG_WORK_PHONE                    0
# FLAG_CONT_MOBILE                   0
# FLAG_PHONE                         0
# FLAG_EMAIL                         0
# OCCUPATION_TYPE                18734
# CNT_FAM_MEMBERS                    0
# REGION_RATING_CLIENT               0
# REGION_RATING_CLIENT_W_CITY        0
# REG_REGION_NOT_LIVE_REGION         0
# REG_REGION_NOT_WORK_REGION         0
# LIVE_REGION_NOT_WORK_REGION        0
# REG_CITY_NOT_LIVE_CITY             0
# REG_CITY_NOT_WORK_CITY             0
# LIVE_CITY_NOT_WORK_CITY            0
# ORGANIZATION_TYPE                  0
# EXT_SOURCE_1                   42912
# EXT_SOURCE_2                     130
# EXT_SOURCE_3                   19690
# OBS_30_CNT_SOCIAL_CIRCLE         181
# DEF_30_CNT_SOCIAL_CIRCLE         181
# OBS_60_CNT_SOCIAL_CIRCLE         181
# DEF_60_CNT_SOCIAL_CIRCLE         181
# DAYS_LAST_PHONE_CHANGE             0
# AMT_REQ_CREDIT_BUREAU_HOUR      8513
# AMT_REQ_CREDIT_BUREAU_MON       8513
# AMT_REQ_CREDIT_BUREAU_QRT       8513
# AMT_REQ_CREDIT_BUREAU_YEAR      8513
# dtype: int64

# %% [markdown]
# #Encoding Categorical Variables¶
#
# Before we go any further, we need to deal with pesky categorical variables. A machine learning model unfortunately cannot deal with categorical variables (except for some models such as LightGBM). Therefore, we have to find a way to encode (represent) these variables as numbers before handing them off to the model. There are two main ways to carry out this process:
#
# *   Label encoding
# *   One-hot encoding

# %% [markdown]
# # Label Encoding and One-Hot Encoding¶
#
# Let's implement the policy described above: for any categorical variable (dtype == object) with 2 unique categories, we will use label encoding, and for any categorical variable with more than 2 unique categories, we will use one-hot encoding.
#
# For label encoding, we use the Scikit-Learn LabelEncoder and for one-hot encoding, the pandas get_dummies(df) function.

# %%
# sklearn preprocessing for dealing with categorical variables
from sklearn.preprocessing import LabelEncoder

# Create a label encoder object
le = LabelEncoder()
le_count = 0

# Iterate through the columns
for col in train:
    if train[col].dtype == 'object':
        # If 2 or fewer unique categories
        if len(list(train[col].unique())) <= 2:
            # Train on the training data
            le.fit(train[col])
            # Transform both training and testing data
            train[col] = le.transform(train[col])
            test[col] = le.transform(test[col])

            # Keep track of how many columns were label encoded
            le_count += 1

print('%d columns were label encoded.' % le_count)
# Out:
# 1 columns were label encoded.

# %%
# one-hot encoding of categorical variables
train = pd.get_dummies(train)
test = pd.get_dummies(test)

print('Training Features shape: ', train.shape)
print('Testing Features shape: ', test.shape)
# Out:
# Training Features shape:  (171202, 156)
# Testing Features shape:  (61500, 153)

# %%
train_labels = train['TARGET']

# Align the training and testing data, keep only columns present in both dataframes
train, test = train.align(test, join = 'inner', axis = 1)

# Add the target back in
train['TARGET'] = train_labels

print('Training Features shape: ', train.shape)
print('Testing Features shape: ', test.shape)
# Out:
# Training Features shape:  (171202, 154)
# Testing Features shape:  (61500, 153)

# %% [markdown]
# #### 1.2.2 各特徴量の可視化・分析
# ここでは、各特徴量について可視化を行い、どのような特徴があるのか分析します。

# %%
# 目的変数（債務不履行かどうか）の分布
sns.countplot(data=train, x="TARGET")
plt.show()

# %% [markdown]
# 目的変数の分布が大きく偏っていることが分かります。このように目的変数の分布が大きく偏っているデータのことを不均衡データと呼びます。
#
#
# 不均衡データを扱う際は、特に評価指標の選び方に注意する必要があります。例えば、今回の評価指標として正解率（Accuracy）を選択すると、全て0と予測するだけで高正解率となることがわかると思います。このような適切でない評価指標を選択すると機械学習モデルがうまく学習できない原因となります。
#
# また、不均衡データへの対処として、目的変数の分布を均衡にしようとするアプローチもあります。多い方の目的変数のデータを減らす手法をアンダーサンプリング、少ない方の目的変数のデータを増やす方法をオーバーサンプリングと呼びます。

# %%
# NAME_CONTRACT_TYPE
sns.countplot(data=train, x="NAME_CONTRACT_TYPE")
plt.show()

# %%
# CNT_CHILDREN
#sns.countplot(data=train, x="NAME_CONTRACT_TYPE")
sns.countplot(data=train, x="CNT_CHILDREN")
plt.show()

# %%
# CNT_FAM_MEMBERS
plt.figure(figsize=(30, 10))
sns.countplot(data=train, x="CNT_FAM_MEMBERS")
plt.tick_params(axis="x", rotation=90)
plt.show()

# %%
# DAYS_BIRTHの分布
#print((train['DAYS_BIRTH'] / -365).describe())
#train['DAYS_BIRTH'] = (train['DAYS_BIRTH'] / -365)
#sns.displot(data=train, x="DAYS_BIRTH")
#plt.show()

# %%
print(train['DAYS_EMPLOYED'].describe())
# Out:
# count    171202.000000
# mean      63960.411969
# std      141401.513149
# min      -17912.000000
# 25%       -2772.000000
# 50%       -1215.000000
# 75%        -288.000000
# max      365243.000000
# Name: DAYS_EMPLOYED, dtype: float64

# %%
train['DAYS_EMPLOYED'].plot.hist(title = 'Days Employment Histogram');
plt.xlabel('Days Employment');

# %%
anom = train[train['DAYS_EMPLOYED'] == 365243]
non_anom = train[train['DAYS_EMPLOYED'] != 365243]
print('The non-anomalies default on %0.2f%% of loans' % (100 * non_anom['TARGET'].mean()))
print('The anomalies default on %0.2f%% of loans' % (100 * anom['TARGET'].mean()))
print('There are %d anomalous days of employment' % len(anom))
# Out:
# The non-anomalies default on 8.66% of loans
# The anomalies default on 5.42% of loans
# There are 30898 anomalous days of employment

# %%
# Create an anomalous flag column
train['DAYS_EMPLOYED_ANOM'] = train["DAYS_EMPLOYED"] == 365243

# Replace the anomalous values with nan
train['DAYS_EMPLOYED'].replace({365243: np.nan}, inplace = True)

train['DAYS_EMPLOYED'].plot.hist(title = 'Days Employment Histogram');
plt.xlabel('Days Employment');

# %%
# ヒストグラムの描写
# x軸のラベルを指定
#plt.xlabel('DAYS_EMPLOYED', fontsize=15)
#plt.xlabel('hist', fontsize=15)
#plt.hist(x=train['DAYS_EMPLOYED'], bins=10, range=(-20000, 0))

# %%
test['DAYS_EMPLOYED_ANOM'] = test["DAYS_EMPLOYED"] == 365243
test["DAYS_EMPLOYED"].replace({365243: np.nan}, inplace = True)

print('There are %d anomalies in the test data out of %d entries' % (test["DAYS_EMPLOYED_ANOM"].sum(), len(test)))
# Out:
# There are 10565 anomalies in the test data out of 61500 entries

# %%
train['DAYS_ID_PUBLISH'].plot.hist(title = 'DAYS_ID_PUBLISH Histogram');
plt.xlabel('DAYS_ID_PUBLISH');

# %% [markdown]
# # Correlations¶
#
# Now that we have dealt with the categorical variables and the outliers, let's continue with the EDA. One way to try and understand the data is by looking for correlations between the features and the target. We can calculate the Pearson correlation coefficient between every variable and the target using the .corr dataframe method.
#
# The correlation coefficient is not the greatest method to represent "relevance" of a feature, but it does give us an idea of possible relationships within the data. Some general interpretations of the absolute value of the correlation coefficent are:
#
#     .00-.19 “very weak”
#     .20-.39 “weak”
#     .40-.59 “moderate”
#     .60-.79 “strong”
#     .80-1.0 “very strong”

# %%
# Find correlations with the target and sort
correlations = train.corr()['TARGET'].sort_values()

# Display correlations
print('Most Positive Correlations:\n', correlations.tail(15))
print('\nMost Negative Correlations:\n', correlations.head(15))
# Out:
# Most Positive Correlations:
#  OWN_CAR_AGE                                          0.040035
# DAYS_REGISTRATION                                    0.041669
# REG_CITY_NOT_LIVE_CITY                               0.043829
# FLAG_EMP_PHONE                                       0.045646
# NAME_EDUCATION_TYPE_Secondary / secondary special    0.048799
# REG_CITY_NOT_WORK_CITY                               0.049438
# DAYS_ID_PUBLISH                                      0.052567
# CODE_GENDER_M                                        0.054457
# DAYS_LAST_PHONE_CHANGE                               0.055195
# NAME_INCOME_TYPE_Working                             0.055869
# REGION_RATING_CLIENT                                 0.058984
# REGION_RATING_CLIENT_W_CITY                          0.061132
# DAYS_EMPLOYED                                        0.073608
# DAYS_BIRTH                                           0.079541
# TARGET                                               1.000000
# Name: TARGET, dtype: float64
#
# Most Negative Correlations:
#  EXT_SOURCE_3                           -0.178317
# EXT_SOURCE_2                           -0.162562
# EXT_SOURCE_1                           -0.154050
# NAME_EDUCATION_TYPE_Higher education   -0.056270
# CODE_GENDER_F                          -0.054442
# NAME_INCOME_TYPE_Pensioner             -0.045726
# DAYS_EMPLOYED_ANOM                     -0.045626
# ORGANIZATION_TYPE_XNA                  -0.045626
# AMT_GOODS_PRICE                        -0.041909
# REGION_POPULATION_RELATIVE             -0.038259
# AMT_CREDIT                             -0.032727
# NAME_CONTRACT_TYPE                     -0.029946
# NAME_HOUSING_TYPE_House / apartment    -0.029776
# NAME_FAMILY_STATUS_Married             -0.025197
# OCCUPATION_TYPE_Accountants            -0.023151
# Name: TARGET, dtype: float64

# %%
# Find the correlation of the positive days since birth and target
train['DAYS_BIRTH'] = abs(train['DAYS_BIRTH'])
train['DAYS_BIRTH'].corr(train['TARGET'])
# Out:
# -0.07954132269839942

# %%
train['DAYS_EMPLOYED'] = abs(train['DAYS_EMPLOYED'])
train['DAYS_EMPLOYED'].corr(train['TARGET'])
# Out:
# -0.07360761123097671

# %%
train['DAYS_ID_PUBLISH'] = abs(train['DAYS_ID_PUBLISH'])
train['DAYS_ID_PUBLISH'].corr(train['TARGET'])
# Out:
# -0.05256731275680315

# %%
# Set the style of plots
plt.style.use('fivethirtyeight')

# Plot the distribution of ages in years
plt.hist(train['DAYS_BIRTH'] / 365, edgecolor = 'k', bins = 25)
plt.title('Age of Client'); plt.xlabel('Age (years)'); plt.ylabel('Count');

# %%
plt.figure(figsize = (10, 8))

# KDE plot of loans that were repaid on time
sns.kdeplot(train.loc[train['TARGET'] == 0, 'DAYS_BIRTH'] / 365, label = "target == 0")

# KDE plot of loans which were not repaid on time
sns.kdeplot(train.loc[train['TARGET'] == 1, 'DAYS_BIRTH'] / 365, label = 'target == 1')

# Labeling of plot
plt.xlabel('Age (years)'); plt.ylabel('Density'); plt.title('Distribution of Ages');

# %%
plt.figure(figsize = (10, 8))

# KDE plot of loans that were repaid on time
sns.kdeplot(train.loc[train['TARGET'] == 0, 'OBS_60_CNT_SOCIAL_CIRCLE'], label = "target == 0")

# KDE plot of loans which were not repaid on time
sns.kdeplot(train.loc[train['TARGET'] == 1, 'OBS_60_CNT_SOCIAL_CIRCLE'], label = 'target == 1')

# Labeling of plot
#plt.xlabel('years'); plt.ylabel('Density'); plt.title('Distribution of AMT_REQ_CREDIT_BUREAU_YEAR');
# Out:
# <Axes: xlabel='OBS_60_CNT_SOCIAL_CIRCLE', ylabel='Density'>

# %%
plt.figure(figsize = (10, 8))

# KDE plot of loans that were repaid on time
sns.kdeplot(train.loc[train['TARGET'] == 0, 'DAYS_ID_PUBLISH'] / 365, label = "target == 0")

# KDE plot of loans which were not repaid on time
sns.kdeplot(train.loc[train['TARGET'] == 1, 'DAYS_ID_PUBLISH'] / 365, label = 'target == 1')

# Labeling of plot
plt.xlabel('years'); plt.ylabel('Density'); plt.title('Distribution of DAYS_ID_PUBLISH');

# %%
# Age information into a separate dataframe
age_data = train[['TARGET', 'DAYS_BIRTH']]
age_data['YEARS_BIRTH'] = age_data['DAYS_BIRTH'] / 365

# Bin the age data
age_data['YEARS_BINNED'] = pd.cut(age_data['YEARS_BIRTH'], bins = np.linspace(20, 70, num = 11))
age_data.head(10)
# Out:
#    TARGET  DAYS_BIRTH  YEARS_BIRTH  YEARS_BINNED
# 0       0        9233    25.295890  (25.0, 30.0]
# 1       0       20148    55.200000  (55.0, 60.0]
# 2       0       18496    50.673973  (50.0, 55.0]
# 3       0       24177    66.238356  (65.0, 70.0]
# 4       1       10685    29.273973  (25.0, 30.0]
# 5       1       16795    46.013699  (45.0, 50.0]
# 6       0       14519    39.778082  (35.0, 40.0]
# 7       1        8624    23.627397  (20.0, 25.0]
# 8       0       14614    40.038356  (40.0, 45.0]
# 9       1       17604    48.230137  (45.0, 50.0]

# %%
# Group by the bin and calculate averages
age_groups  = age_data.groupby('YEARS_BINNED').mean()
age_groups
# Out:
#                 TARGET    DAYS_BIRTH  YEARS_BIRTH
# YEARS_BINNED
# (20.0, 25.0]  0.121158   8529.472370    23.368417
# (25.0, 30.0]  0.113253  10154.840252    27.821480
# (30.0, 35.0]  0.104347  11853.590292    32.475590
# (35.0, 40.0]  0.087437  13707.096396    37.553689
# (40.0, 45.0]  0.079911  15498.153588    42.460695
# (45.0, 50.0]  0.074576  17323.833949    47.462559
# (50.0, 55.0]  0.065109  19195.188720    52.589558
# (55.0, 60.0]  0.055200  20980.426906    57.480622
# (60.0, 65.0]  0.053512  22777.943940    62.405326
# (65.0, 70.0]  0.034308  24286.833297    66.539269

# %%
plt.figure(figsize = (8, 8))

# Graph the age bins and the average of the target as a bar plot
plt.bar(age_groups.index.astype(str), 100 * age_groups['TARGET'])

# Plot labeling
plt.xticks(rotation = 75); plt.xlabel('Age Group (years)'); plt.ylabel('Failure to Repay (%)')
plt.title('Failure to Repay by Age Group');

# %% [markdown]
# There is a clear trend: younger applicants are more likely to not repay the loan! The rate of failure to repay is above 10% for the youngest three age groups and beolow 5% for the oldest age group.
#
# This is information that could be directly used by the bank: because younger clients are less likely to repay the loan, maybe they should be provided with more guidance or financial planning tips. This does not mean the bank should discriminate against younger clients, but it would be smart to take precautionary measures to help younger clients pay on time.

# %% [markdown]
# #Exterior Sources¶
#
# The 3 variables with the strongest negative correlations with the target are EXT_SOURCE_1, EXT_SOURCE_2, and EXT_SOURCE_3. According to the documentation, these features represent a "normalized score from external data source". I'm not sure what this exactly means, but it may be a cumulative sort of credit rating made using numerous sources of data.
#
# Let's take a look at these variables.
#
# First, we can show the correlations of the EXT_SOURCE features with the target and with each other.

# %%
#train['OBS_DEF_60'] = train['DEF_60_CNT_SOCIAL_CIRCLE'] /train['OBS_60_CNT_SOCIAL_CIRCLE']
#test['OBS_DEF_60'] = test['DEF_60_CNT_SOCIAL_CIRCLE'] /test['OBS_60_CNT_SOCIAL_CIRCLE']

train['DEF_OBS'] = (train['DEF_30_CNT_SOCIAL_CIRCLE'] + train['DEF_60_CNT_SOCIAL_CIRCLE']) / (train['OBS_30_CNT_SOCIAL_CIRCLE'] + train['OBS_60_CNT_SOCIAL_CIRCLE'])
test['DEF_OBS'] = (test['DEF_30_CNT_SOCIAL_CIRCLE'] + test['DEF_60_CNT_SOCIAL_CIRCLE']) / (test['OBS_30_CNT_SOCIAL_CIRCLE'] + test['OBS_60_CNT_SOCIAL_CIRCLE'])

# %%
# Extract the EXT_SOURCE variables and show correlations
#ext_data = train[['TARGET', 'EXT_SOURCE_1', 'EXT_SOURCE_2', 'EXT_SOURCE_3', 'DAYS_BIRTH']]
#ext_data = train[['TARGET', 'EXT_SOURCE_1', 'EXT_SOURCE_2', 'EXT_SOURCE_3', 'DAYS_BIRTH','DAYS_EMPLOYED']]
ext_data = train[['TARGET', 'EXT_SOURCE_1', 'EXT_SOURCE_2', 'EXT_SOURCE_3', 'DAYS_BIRTH','DAYS_EMPLOYED','DAYS_ID_PUBLISH','CNT_FAM_MEMBERS','OBS_60_CNT_SOCIAL_CIRCLE','DEF_60_CNT_SOCIAL_CIRCLE','DEF_OBS','NAME_EDUCATION_TYPE_Higher education']]
ext_data_corrs = ext_data.corr()
ext_data_corrs
# Out:
#                                         TARGET  EXT_SOURCE_1  EXT_SOURCE_2  \
# TARGET                                1.000000     -0.154050     -0.162562
# EXT_SOURCE_1                         -0.154050      1.000000      0.213446
# EXT_SOURCE_2                         -0.162562      0.213446      1.000000
# EXT_SOURCE_3                         -0.178317      0.187324      0.109595
# DAYS_BIRTH                           -0.079541      0.598563      0.089463
# DAYS_EMPLOYED                        -0.073608      0.245514      0.094160
# DAYS_ID_PUBLISH                      -0.052567      0.128672      0.051561
# CNT_FAM_MEMBERS                       0.008036     -0.097739      0.000791
# OBS_60_CNT_SOCIAL_CIRCLE              0.011507     -0.029866     -0.020173
# DEF_60_CNT_SOCIAL_CIRCLE              0.033064     -0.031736     -0.033972
# DEF_OBS                               0.042338     -0.029128     -0.042015
# NAME_EDUCATION_TYPE_Higher education -0.056270      0.131821      0.126673
#
#                                       EXT_SOURCE_3  DAYS_BIRTH  DAYS_EMPLOYED  \
# TARGET                                   -0.178317   -0.079541      -0.073608
# EXT_SOURCE_1                              0.187324    0.598563       0.245514
# EXT_SOURCE_2                              0.109595    0.089463       0.094160
# EXT_SOURCE_3                              1.000000    0.207948       0.130494
# DAYS_BIRTH                                0.207948    1.000000       0.352797
# DAYS_EMPLOYED                             0.130494    0.352797       1.000000
# DAYS_ID_PUBLISH                           0.131682    0.273862       0.089489
# CNT_FAM_MEMBERS                          -0.026384   -0.279113      -0.026411
# OBS_60_CNT_SOCIAL_CIRCLE                 -0.001493   -0.007877       0.001133
# DEF_60_CNT_SOCIAL_CIRCLE                 -0.034114   -0.001096      -0.013088
# DEF_OBS                                  -0.048043    0.005048      -0.022194
# NAME_EDUCATION_TYPE_Higher education     -0.025705   -0.117386      -0.003477
#
#                                       DAYS_ID_PUBLISH  CNT_FAM_MEMBERS  \
# TARGET                                      -0.052567         0.008036
# EXT_SOURCE_1                                 0.128672        -0.097739
# EXT_SOURCE_2                                 0.051561         0.000791
# EXT_SOURCE_3                                 0.131682        -0.026384
# DAYS_BIRTH                                   0.273862        -0.279113
# DAYS_EMPLOYED                                0.089489        -0.026411
# DAYS_ID_PUBLISH                              1.000000         0.021983
# CNT_FAM_MEMBERS                              0.021983         1.000000
# OBS_60_CNT_SOCIAL_CIRCLE                     0.011709         0.024830
# DEF_60_CNT_SOCIAL_CIRCLE                    -0.004605        -0.009273
# DEF_OBS                                     -0.010852        -0.025643
# NAME_EDUCATION_TYPE_Higher education        -0.026008         0.025696
#
#                                       OBS_60_CNT_SOCIAL_CIRCLE  \
# TARGET                                                0.011507
# EXT_SOURCE_1                                         -0.029866
# EXT_SOURCE_2                                         -0.020173
# EXT_SOURCE_3                                         -0.001493
# DAYS_BIRTH                                           -0.007877
# DAYS_EMPLOYED                                         0.001133
# DAYS_ID_PUBLISH                                       0.011709
# CNT_FAM_MEMBERS                                       0.024830
# OBS_60_CNT_SOCIAL_CIRCLE                              1.000000
# DEF_60_CNT_SOCIAL_CIRCLE                              0.230731
# DEF_OBS                                              -0.173885
# NAME_EDUCATION_TYPE_Higher education                 -0.048323
#
#                                       DEF_60_CNT_SOCIAL_CIRCLE   DEF_OBS  \
# TARGET                                                0.033064  0.042338
# EXT_SOURCE_1                                         -0.031736 -0.029128
# EXT_SOURCE_2                                         -0.033972 -0.042015
# EXT_SOURCE_3                                         -0.034114 -0.048043
# DAYS_BIRTH                                           -0.001096  0.005048
# DAYS_EMPLOYED                                        -0.013088 -0.022194
# DAYS_ID_PUBLISH                                      -0.004605 -0.010852
# CNT_FAM_MEMBERS                                      -0.009273 -0.025643
# OBS_60_CNT_SOCIAL_CIRCLE                              0.230731 -0.173885
# DEF_60_CNT_SOCIAL_CIRCLE                              1.000000  0.751129
# DEF_OBS                                               0.751129  1.000000
# NAME_EDUCATION_TYPE_Higher education                 -0.031098 -0.024416
#
#                                       NAME_EDUCATION_TYPE_Higher education
# TARGET                                                           -0.056270
# EXT_SOURCE_1                                                      0.131821
# EXT_SOURCE_2                                                      0.126673
# EXT_SOURCE_3                                                     -0.025705
# DAYS_BIRTH                                                       -0.117386
# DAYS_EMPLOYED                                                    -0.003477
# DAYS_ID_PUBLISH                                                  -0.026008
# CNT_FAM_MEMBERS                                                   0.025696
# OBS_60_CNT_SOCIAL_CIRCLE                                         -0.048323
# DEF_60_CNT_SOCIAL_CIRCLE                                         -0.031098
# DEF_OBS                                                          -0.024416
# NAME_EDUCATION_TYPE_Higher education                              1.000000

# %%
plt.figure(figsize = (8, 6))

# Heatmap of correlations
sns.heatmap(ext_data_corrs, cmap = plt.cm.RdYlBu_r, vmin = -0.25, annot = True, vmax = 0.6)
plt.title('Correlation Heatmap');

# %%
plt.figure(figsize = (10, 12))

# iterate through the sources
for i, source in enumerate(['EXT_SOURCE_1', 'EXT_SOURCE_2', 'EXT_SOURCE_3','NAME_EDUCATION_TYPE_Higher education','DEF_OBS']):

    # create a new subplot for each source
    plt.subplot(5, 1, i + 1)
    # plot repaid loans
    sns.kdeplot(train.loc[train['TARGET'] == 0, source], label = 'target == 0')
    # plot loans that were not repaid
    sns.kdeplot(train.loc[train['TARGET'] == 1, source], label = 'target == 1')

    # Label the plots
    plt.title('Distribution of %s by Target Value' % source)
    plt.xlabel('%s' % source); plt.ylabel('Density');

plt.tight_layout(h_pad = 2.5)

# %%
# Copy the data for plotting
#plot_data = ext_data.drop(columns = ['DAYS_BIRTH']).copy()

# Add in the age of the client in years
#plot_data['YEARS_BIRTH'] = age_data['YEARS_BIRTH']

# Drop na values and limit to first 100000 rows
#plot_data = plot_data.dropna().loc[:100000, :]

# Function to calculate correlation coefficient between two columns
#def corr_func(x, y, **kwargs):
#    r = np.corrcoef(x, y)[0][1]
#    ax = plt.gca()
#    ax.annotate("r = {:.2f}".format(r),
#                xy=(.2, .8), xycoords=ax.transAxes,
#                size = 20)

# Create the pairgrid object
#grid = sns.PairGrid(data = plot_data, size = 3, diag_sharey=False,
#                    hue = 'TARGET',
#                    vars = [x for x in list(plot_data.columns) if x != 'TARGET'])

#grid = sns.PairGrid(data = plot_data, diag_sharey=False,
#                    hue = 'TARGET',
#                    vars = [x for x in list(plot_data.columns) if x != 'TARGET'])


# Upper is a scatter plot
#grid.map_upper(plt.scatter, alpha = 0.2)

# Diagonal is a histogram
#grid.map_diag(sns.kdeplot)

# Bottom is density plot
#grid.map_lower(sns.kdeplot, cmap = plt.cm.OrRd_r);

#plt.suptitle('Ext Source and Age Features Pairs Plot', size = 32, y = 1.05);

# %% [markdown]
# AMT_INCOME_TOTALは、通常通り可視化してもうまくグラフが表示されていません。このような場合には、大きな数値を取る少数の外れ値が存在することが原因であると考えられます。今回のようなデータを可視化したい場合は、対数変換を行うと上手くグラフを表示することができます。

# %%
# AMT_INCOME_TOTALの分布（対数変換）
sns.displot(data=train, x="AMT_INCOME_TOTAL", log_scale=10)
plt.show()

# %% [markdown]
# 対数変換してグラフを描画することで、うまく表示することができました。しかし、年収というのは本来連続的な値を取るはずなのに、グラフをみると離散的な値をとっているようです。AMT_INCOME_TOTALの値の種類を確認してみましょう。

# %%
# AMT_INCOME_TOTALの値の種類を確認
len(train["AMT_INCOME_TOTAL"].unique())
# Out:
# 1641

# %%
len(train["NAME_EDUCATION_TYPE_Higher education"].unique())
# Out:
# 2

# %% [markdown]
# trainには171202個のデータが存在するのですが、AMT_INCOME_TOTALは1641種類の値のみで構成されています。具体的に上位10個の値を確認してみましょう。

# %%
# AMT_INCOME_TOTALの上位10個
train["AMT_INCOME_TOTAL"].value_counts().head(10)
# Out:
# AMT_INCOME_TOTAL
# 135000.0    19969
# 112500.0    17320
# 157500.0    14772
# 180000.0    13791
# 90000.0     12481
# 225000.0    11573
# 202500.0     9128
# 67500.0      6130
# 270000.0     6006
# 81000.0      3295
# Name: count, dtype: int64

# %% [markdown]
# どうやらAMT_INCOME_TOTALは正確な年収ではなく、きりの良い数字で集計されたデータであることが分かりました。

# %%
# OWN_CAR_AGEの分布
sns.displot(data=train, x="OWN_CAR_AGE")
plt.show()

# %% [markdown]
# OWN_CAR_AGEは、値のスケールから年単位の値をとっていることが推測できます。また、0〜40あたりまでは自然な分布ですが、60〜70付近に不自然な分布が存在していることが分かります。車の購入年数がこのように急に値が上昇するとは、考えにくいので外れ値であると考えられます。

# %% [markdown]
# ここまで、各特徴量の可視化と分析を行いました。可視化をするのにも工夫が必要だったり、可視化を行うことでデータについての理解が深まることが実感できたと思います。今回扱っていない45種類の特徴量についても、今回の可視化などを参考に各自で可視化・分析を行ってみることで、必ず予測精度の向上につながると思います。

# %% [markdown]
# ## 2. 前処理と特徴量作成
# ここでは、上記の可視化と分析でわかったことを踏まえて、前処理と特徴量の作成を行います。

# %%
# NAME_INCOME_TYPEの数値化（Count Encoding）
#name_type_suite_ce = train_ft["NAME_TYPE_SUITE"].value_counts()
#train_ft["NAME_TYPE_SUITE"] = train_ft["NAME_TYPE_SUITE"].map(name_type_suite_ce)
#test_ft["NAME_TYPE_SUITE"] = test_ft["NAME_TYPE_SUITE"].map(name_type_suite_ce)

# %%
#train_ft['NAME_TYPE_SUITE'].corr(train['TARGET'])

# %%
# NAME_CONTRACT_TYPEの数値化（Label Encoding）
train_ft["NAME_CONTRACT_TYPE"].replace({'Cash loans': 0, 'Revolving loans': 1}, inplace=True)
test_ft["NAME_CONTRACT_TYPE"].replace({'Cash loans': 0, 'Revolving loans': 1}, inplace=True)

train_ft.head(5)
# Out:
#    NAME_CONTRACT_TYPE      NAME_INCOME_TYPE  AMT_INCOME_TOTAL  OWN_CAR_AGE  \
# 0                   0               Working          112500.0          NaN
# 1                   0             Pensioner          225000.0          NaN
# 2                   0         State servant           54000.0          NaN
# 3                   0             Pensioner           67500.0          NaN
# 4                   0  Commercial associate          157500.0          NaN
#
#         ORGANIZATION_TYPE OCCUPATION_TYPE  TARGET
# 0                  School      Core staff       0
# 1                     XNA             NaN       0
# 2                  Postal      Core staff       0
# 3                     XNA             NaN       0
# 4  Business Entity Type 3         Drivers       1

# %%
# NAME_INCOME_TYPEの数値化（Count Encoding）
name_income_type_ce = train_ft["NAME_INCOME_TYPE"].value_counts()
train_ft["NAME_INCOME_TYPE"] = train_ft["NAME_INCOME_TYPE"].map(name_income_type_ce)
test_ft["NAME_INCOME_TYPE"] = test_ft["NAME_INCOME_TYPE"].map(name_income_type_ce)

train_ft.head(5)
# Out:
#    NAME_CONTRACT_TYPE  NAME_INCOME_TYPE  AMT_INCOME_TOTAL  OWN_CAR_AGE  \
# 0                   0             88268          112500.0          NaN
# 1                   0             30895          225000.0          NaN
# 2                   0             12007           54000.0          NaN
# 3                   0             30895           67500.0          NaN
# 4                   0             40007          157500.0          NaN
#
#         ORGANIZATION_TYPE OCCUPATION_TYPE  TARGET
# 0                  School      Core staff       0
# 1                     XNA             NaN       0
# 2                  Postal      Core staff       0
# 3                     XNA             NaN       0
# 4  Business Entity Type 3         Drivers       1

# %%
train_ft['NAME_INCOME_TYPE'].corr(train['TARGET'])
# Out:
# 0.058168254818843246

# %%
# NAME_INCOME_TYPEの数値化（Count Encoding）
#name_education_type_ce = train_ft["NAME_EDUCATION_TYPE"].value_counts()
#train_ft["NAME_EDUCATION_TYPE"] = train_ft["NAME_EDUCATION_TYPE"].map(name_education_type_ce)
#test_ft["NAME_EDUCATION_TYPE"] = test_ft["NAME_EDUCATION_TYPE"].map(name_education_type_ce)

#train_ft.head(5)

# %%
#train_ft['NAME_EDUCATION_TYPE'].corr(train['TARGET'])

# %%
#NAME_HOUSING_TYPE
#name_housing_type_ce = train_ft["NAME_HOUSING_TYPE"].value_counts()
#train_ft["NAME_HOUSING_TYPE"] = train_ft["NAME_HOUSING_TYPE"].map(name_housing_type_ce)
#test_ft["NAME_HOUSING_TYPE"] = test_ft["NAME_HOUSING_TYPE"].map(name_housing_type_ce)

# %%
#train_ft['NAME_HOUSING_TYPE'].corr(train['TARGET'])

# %%
# ORGANIZATION_TYPEの数値化（Count Encoding）
organization_ce = train_ft["ORGANIZATION_TYPE"].value_counts()
train_ft["ORGANIZATION_TYPE"] = train_ft["ORGANIZATION_TYPE"].map(organization_ce)
test_ft["ORGANIZATION_TYPE"] = test_ft["ORGANIZATION_TYPE"].map(organization_ce)

train_ft.head(5)
# Out:
#    NAME_CONTRACT_TYPE  NAME_INCOME_TYPE  AMT_INCOME_TOTAL  OWN_CAR_AGE  \
# 0                   0             88268          112500.0          NaN
# 1                   0             30895          225000.0          NaN
# 2                   0             12007           54000.0          NaN
# 3                   0             30895           67500.0          NaN
# 4                   0             40007          157500.0          NaN
#
#    ORGANIZATION_TYPE OCCUPATION_TYPE  TARGET
# 0               4991      Core staff       0
# 1              30898             NaN       0
# 2               1185      Core staff       0
# 3              30898             NaN       0
# 4              37943         Drivers       1

# %%
occupation_type_ce = train_ft["OCCUPATION_TYPE"].value_counts()
train_ft["OCCUPATION_TYPE"] = train_ft["OCCUPATION_TYPE"].map(organization_ce)
test_ft["OCCUPATION_TYPE"] = test_ft["OCCUPATION_TYPE"].map(organization_ce)

# %%
# OWN_CAR_AGEの60以上の値（外れ値）を欠損値扱いする
train_ft.loc[train["OWN_CAR_AGE"] >= 60, "OWN_CAR_AGE"] = np.nan
test_ft.loc[test["OWN_CAR_AGE"] >= 60, "OWN_CAR_AGE"] = np.nan

# %%
# OWN_CAR_AGEをグループ分け
train_ft["OWN_CAR_AGE"] = train_ft["OWN_CAR_AGE"] // 10
test_ft["OWN_CAR_AGE"] = test_ft["OWN_CAR_AGE"] // 10

train_ft["OWN_CAR_AGE"].unique()
# Out:
# array([nan,  0.,  2.,  1.,  3.,  4.,  5.])

# %%
# OWN_CAR_AGEをOne Hot Encoding
train_car_age_ohe = pd.get_dummies(train["OWN_CAR_AGE"]).add_prefix("OWN_CAR_AGE_")
test_car_age_ohe = pd.get_dummies(test["OWN_CAR_AGE"]).add_prefix("OWN_CAR_AGE_")

train_ft = pd.concat([train_ft, train_car_age_ohe], axis=1)
test_ft = pd.concat([test_ft, test_car_age_ohe], axis=1)

train_ft.drop('OWN_CAR_AGE', axis=1, inplace=True)
test_ft.drop('OWN_CAR_AGE', axis=1, inplace=True)

train_ft.head(5)
# Out:
#    NAME_CONTRACT_TYPE  NAME_INCOME_TYPE  AMT_INCOME_TOTAL  ORGANIZATION_TYPE  \
# 0                   0             88268          112500.0               4991
# 1                   0             30895          225000.0              30898
# 2                   0             12007           54000.0               1185
# 3                   0             30895           67500.0              30898
# 4                   0             40007          157500.0              37943
#
#    OCCUPATION_TYPE  TARGET  OWN_CAR_AGE_0.0  OWN_CAR_AGE_1.0  OWN_CAR_AGE_2.0  \
# 0              NaN       0            False            False            False
# 1              NaN       0            False            False            False
# 2              NaN       0            False            False            False
# 3              NaN       0            False            False            False
# 4              NaN       1            False            False            False
#
#    OWN_CAR_AGE_3.0  ...  OWN_CAR_AGE_44.0  OWN_CAR_AGE_45.0  OWN_CAR_AGE_46.0  \
# 0            False  ...             False             False             False
# 1            False  ...             False             False             False
# 2            False  ...             False             False             False
# 3            False  ...             False             False             False
# 4            False  ...             False             False             False
#
#    OWN_CAR_AGE_49.0  OWN_CAR_AGE_54.0  OWN_CAR_AGE_55.0  OWN_CAR_AGE_57.0  \
# 0             False             False             False             False
# 1             False             False             False             False
# 2             False             False             False             False
# 3             False             False             False             False
# 4             False             False             False             False
#
#    OWN_CAR_AGE_64.0  OWN_CAR_AGE_65.0  OWN_CAR_AGE_91.0
# 0             False             False             False
# 1             False             False             False
# 2             False             False             False
# 3             False             False             False
# 4             False             False             False
#
# [5 rows x 60 columns]

# %%
test_ft.head(5)
# Out:
#    NAME_CONTRACT_TYPE  NAME_INCOME_TYPE  AMT_INCOME_TOTAL  ORGANIZATION_TYPE  \
# 0                   0             88268          144000.0               3866
# 1                   0             88268          103500.0               4991
# 2                   0             40007          180000.0               4336
# 3                   1             88268          225000.0              37943
# 4                   0             88268          144000.0              37943
#
#    OCCUPATION_TYPE  OWN_CAR_AGE_0.0  OWN_CAR_AGE_1.0  OWN_CAR_AGE_2.0  \
# 0              NaN            False            False            False
# 1              NaN            False            False            False
# 2              NaN            False            False            False
# 3              NaN            False            False            False
# 4              NaN            False            False            False
#
#    OWN_CAR_AGE_3.0  OWN_CAR_AGE_4.0  ...  OWN_CAR_AGE_46.0  OWN_CAR_AGE_49.0  \
# 0            False            False  ...             False             False
# 1            False            False  ...             False             False
# 2            False            False  ...             False             False
# 3            False            False  ...             False             False
# 4            False            False  ...             False             False
#
#    OWN_CAR_AGE_50.0  OWN_CAR_AGE_51.0  OWN_CAR_AGE_54.0  OWN_CAR_AGE_55.0  \
# 0             False             False             False             False
# 1             False             False             False             False
# 2             False             False             False             False
# 3             False             False             False             False
# 4             False             False             False             False
#
#    OWN_CAR_AGE_64.0  OWN_CAR_AGE_65.0  OWN_CAR_AGE_69.0  OWN_CAR_AGE_91.0
# 0             False             False             False             False
# 1             False             False             False             False
# 2             False             False             False             False
# 3             False             False             False             False
# 4             False             False             False             False
#
# [5 rows x 61 columns]

# %% [markdown]
# Polynomial features
#
# Domain knowledge features

# %%
# Make a new dataframe for polynomial features
poly_features = train[['EXT_SOURCE_1', 'EXT_SOURCE_2', 'EXT_SOURCE_3','DAYS_BIRTH','TARGET']]
poly_features_test = test[['EXT_SOURCE_1', 'EXT_SOURCE_2', 'EXT_SOURCE_3','DAYS_BIRTH']]

# imputer for handling missing values
#from sklearn.preprocessing import Imputer
from sklearn.impute import SimpleImputer

#imputer = Imputer(strategy = 'median')
imputer = SimpleImputer(strategy = 'median')

poly_target = poly_features['TARGET']

poly_features = poly_features.drop(columns = ['TARGET'])

# Need to impute missing values
poly_features = imputer.fit_transform(poly_features)
poly_features_test = imputer.transform(poly_features_test)

from sklearn.preprocessing import PolynomialFeatures

# Create the polynomial object with specified degree
poly_transformer = PolynomialFeatures(degree = 3)

# %%
# Train the polynomial features
poly_transformer.fit(poly_features)

# Transform the features
poly_features = poly_transformer.transform(poly_features)
poly_features_test = poly_transformer.transform(poly_features_test)
print('Polynomial Features shape: ', poly_features.shape)
print('Polynomial Features test shape: ', poly_features_test.shape)
# Out:
# Polynomial Features shape:  (171202, 35)
# Polynomial Features test shape:  (61500, 35)

# %%
poly_transformer.get_feature_names_out(input_features = ['EXT_SOURCE_1', 'EXT_SOURCE_2', 'EXT_SOURCE_3','DAYS_BIRTH'])[:15]
# Out:
# array(['1', 'EXT_SOURCE_1', 'EXT_SOURCE_2', 'EXT_SOURCE_3', 'DAYS_BIRTH',
#        'EXT_SOURCE_1^2', 'EXT_SOURCE_1 EXT_SOURCE_2',
#        'EXT_SOURCE_1 EXT_SOURCE_3', 'EXT_SOURCE_1 DAYS_BIRTH',
#        'EXT_SOURCE_2^2', 'EXT_SOURCE_2 EXT_SOURCE_3',
#        'EXT_SOURCE_2 DAYS_BIRTH', 'EXT_SOURCE_3^2',
#        'EXT_SOURCE_3 DAYS_BIRTH', 'DAYS_BIRTH^2'], dtype=object)

# %%
# Create a dataframe of the features
poly_features = pd.DataFrame(poly_features,
                             columns = poly_transformer.get_feature_names_out(['EXT_SOURCE_1', 'EXT_SOURCE_2','EXT_SOURCE_3','DAYS_BIRTH']))
# Add in the target
poly_features['TARGET'] = poly_target

# Find the correlations with the target
poly_corrs = poly_features.corr()['TARGET'].sort_values()

# Display most negative and most positive
print(poly_corrs.head(10))
print(poly_corrs.tail(5))
# Out:
# EXT_SOURCE_2 EXT_SOURCE_3                -0.190619
# EXT_SOURCE_1 EXT_SOURCE_2 EXT_SOURCE_3   -0.187364
# EXT_SOURCE_2 EXT_SOURCE_3 DAYS_BIRTH     -0.179790
# EXT_SOURCE_2^2 EXT_SOURCE_3              -0.174604
# EXT_SOURCE_2 EXT_SOURCE_3^2              -0.169516
# EXT_SOURCE_1 EXT_SOURCE_2                -0.165062
# EXT_SOURCE_2                             -0.162383
# EXT_SOURCE_2 DAYS_BIRTH                  -0.159863
# EXT_SOURCE_1 EXT_SOURCE_2 DAYS_BIRTH     -0.157203
# EXT_SOURCE_1 EXT_SOURCE_2^2              -0.155854
# Name: TARGET, dtype: float64
# EXT_SOURCE_1^2   -0.075605
# DAYS_BIRTH^3     -0.075583
# EXT_SOURCE_1^3   -0.068726
# TARGET            1.000000
# 1                      NaN
# Name: TARGET, dtype: float64

# %%
train_ft.head(10)
# Out:
#    NAME_CONTRACT_TYPE  NAME_INCOME_TYPE  AMT_INCOME_TOTAL  ORGANIZATION_TYPE  \
# 0                   0             88268          112500.0               4991
# 1                   0             30895          225000.0              30898
# 2                   0             12007           54000.0               1185
# 3                   0             30895           67500.0              30898
# 4                   0             40007          157500.0              37943
# 5                   0             40007          135000.0               3004
# 6                   0             40007          189000.0               1885
# 7                   0             88268          157500.0              37943
# 8                   0             12007          324000.0               1452
# 9                   0             88268          180000.0              21340
#
#    OCCUPATION_TYPE  TARGET  OWN_CAR_AGE_0.0  OWN_CAR_AGE_1.0  OWN_CAR_AGE_2.0  \
# 0              NaN       0            False            False            False
# 1              NaN       0            False            False            False
# 2              NaN       0            False            False            False
# 3              NaN       0            False            False            False
# 4              NaN       1            False            False            False
# 5              NaN       1            False            False            False
# 6              NaN       0            False            False            False
# 7              NaN       1            False            False            False
# 8              NaN       0            False             True            False
# 9              NaN       1            False            False            False
#
#    OWN_CAR_AGE_3.0  ...  OWN_CAR_AGE_44.0  OWN_CAR_AGE_45.0  OWN_CAR_AGE_46.0  \
# 0            False  ...             False             False             False
# 1            False  ...             False             False             False
# 2            False  ...             False             False             False
# 3            False  ...             False             False             False
# 4            False  ...             False             False             False
# 5            False  ...             False             False             False
# 6            False  ...             False             False             False
# 7            False  ...             False             False             False
# 8            False  ...             False             False             False
# 9            False  ...             False             False             False
#
#    OWN_CAR_AGE_49.0  OWN_CAR_AGE_54.0  OWN_CAR_AGE_55.0  OWN_CAR_AGE_57.0  \
# 0             False             False             False             False
# 1             False             False             False             False
# 2             False             False             False             False
# 3             False             False             False             False
# 4             False             False             False             False
# 5             False             False             False             False
# 6             False             False             False             False
# 7             False             False             False             False
# 8             False             False             False             False
# 9             False             False             False             False
#
#    OWN_CAR_AGE_64.0  OWN_CAR_AGE_65.0  OWN_CAR_AGE_91.0
# 0             False             False             False
# 1             False             False             False
# 2             False             False             False
# 3             False             False             False
# 4             False             False             False
# 5             False             False             False
# 6             False             False             False
# 7             False             False             False
# 8             False             False             False
# 9             False             False             False
#
# [10 rows x 60 columns]

# %%
# Put test features into dataframe
poly_features_test = pd.DataFrame(poly_features_test,
                             columns = poly_transformer.get_feature_names_out(['EXT_SOURCE_1','EXT_SOURCE_2','EXT_SOURCE_3','DAYS_BIRTH']))

# Merge polynomial features into training dataframe
poly_features['SK_ID_CURR'] = train['SK_ID_CURR']
train_ft['SK_ID_CURR'] = train['SK_ID_CURR']
train_poly = train_ft.merge(poly_features, on = 'SK_ID_CURR', how = 'left')

# Merge polnomial features into testing dataframe
poly_features_test['SK_ID_CURR'] = test['SK_ID_CURR']
test_ft['SK_ID_CURR'] = test['SK_ID_CURR']
test_poly = test_ft.merge(poly_features_test, on = 'SK_ID_CURR', how = 'left')

# Align the dataframes
train_poly, test_poly = train_poly.align(test_poly, join = 'inner', axis = 1)

# Print out the new shapes
print('Training data with polynomial features shape: ', train_poly.shape)
print('Testing data with polynomial features shape:  ', test_poly.shape)
# Out:
# Training data with polynomial features shape:  (171202, 94)
# Testing data with polynomial features shape:   (61500, 94)

# %%
#train_poly.head(5)
train_poly.columns
# Out:
# Index(['NAME_CONTRACT_TYPE', 'NAME_INCOME_TYPE', 'AMT_INCOME_TOTAL',
#        'ORGANIZATION_TYPE', 'OCCUPATION_TYPE', 'OWN_CAR_AGE_0.0',
#        'OWN_CAR_AGE_1.0', 'OWN_CAR_AGE_2.0', 'OWN_CAR_AGE_3.0',
#        'OWN_CAR_AGE_4.0', 'OWN_CAR_AGE_5.0', 'OWN_CAR_AGE_6.0',
#        'OWN_CAR_AGE_7.0', 'OWN_CAR_AGE_8.0', 'OWN_CAR_AGE_9.0',
#        'OWN_CAR_AGE_10.0', 'OWN_CAR_AGE_11.0', 'OWN_CAR_AGE_12.0',
#        'OWN_CAR_AGE_13.0', 'OWN_CAR_AGE_14.0', 'OWN_CAR_AGE_15.0',
#        'OWN_CAR_AGE_16.0', 'OWN_CAR_AGE_17.0', 'OWN_CAR_AGE_18.0',
#        'OWN_CAR_AGE_19.0', 'OWN_CAR_AGE_20.0', 'OWN_CAR_AGE_21.0',
#        'OWN_CAR_AGE_22.0', 'OWN_CAR_AGE_23.0', 'OWN_CAR_AGE_24.0',
#        'OWN_CAR_AGE_25.0', 'OWN_CAR_AGE_26.0', 'OWN_CAR_AGE_27.0',
#        'OWN_CAR_AGE_28.0', 'OWN_CAR_AGE_29.0', 'OWN_CAR_AGE_30.0',
#        'OWN_CAR_AGE_31.0', 'OWN_CAR_AGE_32.0', 'OWN_CAR_AGE_33.0',
#        'OWN_CAR_AGE_34.0', 'OWN_CAR_AGE_35.0', 'OWN_CAR_AGE_36.0',
#        'OWN_CAR_AGE_37.0', 'OWN_CAR_AGE_38.0', 'OWN_CAR_AGE_39.0',
#        'OWN_CAR_AGE_40.0', 'OWN_CAR_AGE_41.0', 'OWN_CAR_AGE_42.0',
#        'OWN_CAR_AGE_43.0', 'OWN_CAR_AGE_44.0', 'OWN_CAR_AGE_45.0',
#        'OWN_CAR_AGE_46.0', 'OWN_CAR_AGE_49.0', 'OWN_CAR_AGE_54.0',
#        'OWN_CAR_AGE_55.0', 'OWN_CAR_AGE_64.0', 'OWN_CAR_AGE_65.0',
#        'OWN_CAR_AGE_91.0', 'SK_ID_CURR', '1', 'EXT_SOURCE_1', 'EXT_SOURCE_2',
#        'EXT_SOURCE_3', 'DAYS_BIRTH', 'EXT_SOURCE_1^2',
#        'EXT_SOURCE_1 EXT_SOURCE_2', 'EXT_SOURCE_1 EXT_SOURCE_3',
#        'EXT_SOURCE_1 DAYS_BIRTH', 'EXT_SOURCE_2^2',
#        'EXT_SOURCE_2 EXT_SOURCE_3', 'EXT_SOURCE_2 DAYS_BIRTH',
#        'EXT_SOURCE_3^2', 'EXT_SOURCE_3 DAYS_BIRTH', 'DAYS_BIRTH^2',
#        'EXT_SOURCE_1^3', 'EXT_SOURCE_1^2 EXT_SOURCE_2',
#        'EXT_SOURCE_1^2 EXT_SOURCE_3', 'EXT_SOURCE_1^2 DAYS_BIRTH',
#        'EXT_SOURCE_1 EXT_SOURCE_2^2', 'EXT_SOURCE_1 EXT_SOURCE_2 EXT_SOURCE_3',
#        'EXT_SOURCE_1 EXT_SOURCE_2 DAYS_BIRTH', 'EXT_SOURCE_1 EXT_SOURCE_3^2',
#        'EXT_SOURCE_1 EXT_SOURCE_3 DAYS_BIRTH', 'EXT_SOURCE_1 DAYS_BIRTH^2',
#        'EXT_SOURCE_2^3', 'EXT_SOURCE_2^2 EXT_SOURCE_3',
#        'EXT_SOURCE_2^2 DAYS_BIRTH', 'EXT_SOURCE_2 EXT_SOURCE_3^2',
#        'EXT_SOURCE_2 EXT_SOURCE_3 DAYS_BIRTH', 'EXT_SOURCE_2 DAYS_BIRTH^2',
#        'EXT_SOURCE_3^3', 'EXT_SOURCE_3^2 DAYS_BIRTH',
#        'EXT_SOURCE_3 DAYS_BIRTH^2', 'DAYS_BIRTH^3'],
#       dtype='object')

# %%
print(train_poly.isnull().sum())
print(test_poly.isnull().sum())
# Out:
# NAME_CONTRACT_TYPE                0
# NAME_INCOME_TYPE                  0
# AMT_INCOME_TOTAL                  0
# ORGANIZATION_TYPE                 0
# OCCUPATION_TYPE              171202
#                               ...
# EXT_SOURCE_2 DAYS_BIRTH^2         0
# EXT_SOURCE_3^3                    0
# EXT_SOURCE_3^2 DAYS_BIRTH         0
# EXT_SOURCE_3 DAYS_BIRTH^2         0
# DAYS_BIRTH^3                      0
# Length: 94, dtype: int64
# NAME_CONTRACT_TYPE               0
# NAME_INCOME_TYPE                 0
# AMT_INCOME_TOTAL                 0
# ORGANIZATION_TYPE                0
# OCCUPATION_TYPE              61500
#                              ...
# EXT_SOURCE_2 DAYS_BIRTH^2        0
# EXT_SOURCE_3^3                   0
# EXT_SOURCE_3^2 DAYS_BIRTH        0
# EXT_SOURCE_3 DAYS_BIRTH^2        0
# DAYS_BIRTH^3                     0
# Length: 94, dtype: int64

# %%
#from sklearn.preprocessing import MinMaxScaler
#from sklearn.impute import SimpleImputer
#Median imputation of missing values

#train.DAYS_EMPLOYED.fillna(0,inplace=True)
#train.DAYS_EMPLOYED = abs(train["DAYS_EMPLOYED"])

#test.DAYS_EMPLOYED.fillna(0,inplace=True)
#test.DAYS_EMPLOYED = abs(test["DAYS_EMPLOYED"])


#imputer = SimpleImputer(strategy = 'median')
#imputer.fit(train)
#train = (imputer.transform(train))

#imputer.fit(test)
#test = (imputer.transform(test))

# %%
train_domain = train.copy()
test_domain = test.copy()

train_domain['CREDIT_INCOME_PERCENT'] = train_domain['AMT_CREDIT'] / train_domain['AMT_INCOME_TOTAL']
train_domain['ANNUITY_INCOME_PERCENT'] = train_domain['AMT_ANNUITY'] / train_domain['AMT_INCOME_TOTAL']
train_domain['CREDIT_TERM'] = train_domain['AMT_ANNUITY'] / train_domain['AMT_CREDIT']
train_domain['DAYS_EMPLOYED_PERCENT'] = train_domain['DAYS_EMPLOYED'] / train_domain['DAYS_BIRTH']
#train_domain['OBS_CNT_SOCIAL_CIRCLE'] = train_domain['OBS_30_CNT_SOCIAL_CIRCLE'] + train_domain['OBS_60_CNT_SOCIAL_CIRCLE']

train_domain['DAYS_ID_PUBLISH_PERCENT'] = train_domain['DAYS_ID_PUBLISH'] / train_domain['DAYS_BIRTH']

# %%
test_domain['CREDIT_INCOME_PERCENT'] = test_domain['AMT_CREDIT'] / test_domain['AMT_INCOME_TOTAL']
test_domain['ANNUITY_INCOME_PERCENT'] = test_domain['AMT_ANNUITY'] / test_domain['AMT_INCOME_TOTAL']
test_domain['CREDIT_TERM'] = test_domain['AMT_ANNUITY'] / test_domain['AMT_CREDIT']
test_domain['DAYS_EMPLOYED_PERCENT'] = test_domain['DAYS_EMPLOYED'] / test_domain['DAYS_BIRTH']
#test_domain['OBS_CNT_SOCIAL_CIRCLE'] = test_domain['OBS_30_CNT_SOCIAL_CIRCLE'] + test_domain['OBS_60_CNT_SOCIAL_CIRCLE']
test_domain['DAYS_ID_PUBLISH_PERCENT'] = test_domain['DAYS_ID_PUBLISH'] / test_domain['DAYS_BIRTH']

# %%
train_domain.isnull().sum()
# Out:
# SK_ID_CURR                     0
# NAME_CONTRACT_TYPE             0
# CNT_CHILDREN                   0
# AMT_INCOME_TOTAL               0
# AMT_CREDIT                     0
#                            ...
# CREDIT_INCOME_PERCENT          0
# ANNUITY_INCOME_PERCENT         6
# CREDIT_TERM                    6
# DAYS_EMPLOYED_PERCENT      30898
# DAYS_ID_PUBLISH_PERCENT        0
# Length: 161, dtype: int64

# %%
plt.figure(figsize = (12, 20))
# iterate through the new features
for i, feature in enumerate(['CREDIT_INCOME_PERCENT', 'ANNUITY_INCOME_PERCENT', 'CREDIT_TERM', 'DAYS_EMPLOYED_PERCENT','AMT_REQ_CREDIT_BUREAU_HOUR','DAYS_ID_PUBLISH_PERCENT']):

    # create a new subplot for each source
    plt.subplot(6, 1, i + 1)
    # plot repaid loans
    sns.kdeplot(train_domain.loc[train_domain['TARGET'] == 0, feature], label = 'target == 0')
    # plot loans that were not repaid
    sns.kdeplot(train_domain.loc[train_domain['TARGET'] == 1, feature], label = 'target == 1')

    # Label the plots
    plt.title('Distribution of %s by Target Value' % feature)
    plt.xlabel('%s' % feature); plt.ylabel('Density');

plt.tight_layout(h_pad = 2.5)

# %%
train_fix = train_poly.copy()

train_fix['AMT_CREDIT'] = train_domain['AMT_CREDIT']
train_fix['AMT_ANNUITY'] = train_domain['AMT_ANNUITY']
train_fix['AMT_INCOME_TOTAL'] = train_domain['AMT_INCOME_TOTAL']
train_fix['DAYS_EMPLOYED'] = train_domain['DAYS_EMPLOYED']
train_fix['DAYS_BIRTH'] = train_domain['DAYS_BIRTH']

#train_fix['DAYS_ID_PUBLISH'] = train_domain['DAYS_ID_PUBLISH']

#train_fix['AMT_REQ_CREDIT_BUREAU_HOUR'] = train_domain['AMT_REQ_CREDIT_BUREAU_HOUR']
#train_fix['AMT_REQ_CREDIT_BUREAU_MON'] = train_domain['AMT_REQ_CREDIT_BUREAU_MON']
#train_fix['AMT_REQ_CREDIT_BUREAU_QRT'] = train_domain['AMT_REQ_CREDIT_BUREAU_QRT']
#train_fix['AMT_REQ_CREDIT_BUREAU_YEAR'] = train_domain['AMT_REQ_CREDIT_BUREAU_YEAR']

train_fix['DEF_OBS'] = train_domain['DEF_OBS']

train_fix['CREDIT_INCOME_PERCENT'] = train_domain['CREDIT_INCOME_PERCENT']
train_fix['ANNUITY_INCOME_PERCENT'] = train_domain['ANNUITY_INCOME_PERCENT']
train_fix['CREDIT_TERM'] = train_domain['CREDIT_TERM']
train_fix['DAYS_EMPLOYED_PERCENT'] = train_domain['DAYS_EMPLOYED_PERCENT']
#train_fix['DAYS_ID_PUBLISH_PERCENT'] = train_domain['DAYS_ID_PUBLISH_PERCENT']

train_fix.head(5)
# Out:
#    NAME_CONTRACT_TYPE  NAME_INCOME_TYPE  AMT_INCOME_TOTAL  ORGANIZATION_TYPE  \
# 0                   0             88268          112500.0               4991
# 1                   0             30895          225000.0              30898
# 2                   0             12007           54000.0               1185
# 3                   0             30895           67500.0              30898
# 4                   0             40007          157500.0              37943
#
#    OCCUPATION_TYPE  OWN_CAR_AGE_0.0  OWN_CAR_AGE_1.0  OWN_CAR_AGE_2.0  \
# 0              NaN            False            False            False
# 1              NaN            False            False            False
# 2              NaN            False            False            False
# 3              NaN            False            False            False
# 4              NaN            False            False            False
#
#    OWN_CAR_AGE_3.0  OWN_CAR_AGE_4.0  ...  EXT_SOURCE_3 DAYS_BIRTH^2  \
# 0            False            False  ...               4.578429e+07
# 1            False            False  ...               2.245527e+08
# 2            False            False  ...               1.837327e+08
# 3            False            False  ...               4.486382e+08
# 4            False            False  ...               7.638568e+07
#
#    DAYS_BIRTH^3  AMT_CREDIT  AMT_ANNUITY  DAYS_EMPLOYED  DEF_OBS  \
# 0  7.870975e+11    755190.0      36328.5          878.0      NaN
# 1  8.178917e+12    585000.0      16893.0            NaN      NaN
# 2  6.327519e+12    334152.0      18256.5          523.0      0.0
# 3  1.413212e+13    152820.0       8901.0            NaN      NaN
# 4  1.219898e+12    271066.5      21546.0          697.0      NaN
#
#    CREDIT_INCOME_PERCENT  ANNUITY_INCOME_PERCENT  CREDIT_TERM  \
# 0               6.712800                0.322920     0.048105
# 1               2.600000                0.075080     0.028877
# 2               6.188000                0.338083     0.054635
# 3               2.264000                0.131867     0.058245
# 4               1.721057                0.136800     0.079486
#
#    DAYS_EMPLOYED_PERCENT
# 0               0.095094
# 1                    NaN
# 2               0.028276
# 3                    NaN
# 4               0.065232
#
# [5 rows x 102 columns]

# %%
test_fix = test_poly.copy()

test_fix['AMT_CREDIT'] = test_domain['AMT_CREDIT']
test_fix['AMT_ANNUITY'] = test_domain['AMT_ANNUITY']
test_fix['AMT_INCOME_TOTAL'] = test_domain['AMT_INCOME_TOTAL']
test_fix['DAYS_EMPLOYED'] = test_domain['DAYS_EMPLOYED']
test_fix['DAYS_BIRTH'] = test_domain['DAYS_BIRTH']

test_fix['DEF_OBS'] = test_domain['DEF_OBS']

#test_fix['DAYS_ID_PUBLISH'] = test_domain['DAYS_ID_PUBLISH']

#test_fix['AMT_REQ_CREDIT_BUREAU_HOUR'] = test_domain['AMT_REQ_CREDIT_BUREAU_HOUR']
#test_fix['AMT_REQ_CREDIT_BUREAU_MON'] = test_domain['AMT_REQ_CREDIT_BUREAU_MON']
#test_fix['AMT_REQ_CREDIT_BUREAU_QRT'] = test_domain['AMT_REQ_CREDIT_BUREAU_QRT']
#test_fix['AMT_REQ_CREDIT_BUREAU_YEAR'] = test_domain['AMT_REQ_CREDIT_BUREAU_YEAR']

test_fix['CREDIT_INCOME_PERCENT'] = test_domain['CREDIT_INCOME_PERCENT']
test_fix['ANNUITY_INCOME_PERCENT'] = test_domain['ANNUITY_INCOME_PERCENT']
test_fix['CREDIT_TERM'] = test_domain['CREDIT_TERM']
test_fix['DAYS_EMPLOYED_PERCENT'] = test_domain['DAYS_EMPLOYED_PERCENT']
#test_fix['DAYS_ID_PUBLISH_PERCENT'] = test_domain['DAYS_ID_PUBLISH_PERCENT']

#test_fix['OBS_CNT_SOCIAL_CIRCLE'] = test_domain['OBS_CNT_SOCIAL_CIRCLE']

test_fix.head(5)
# Out:
#    NAME_CONTRACT_TYPE  NAME_INCOME_TYPE  AMT_INCOME_TOTAL  ORGANIZATION_TYPE  \
# 0                   0             88268          144000.0               3866
# 1                   0             88268          103500.0               4991
# 2                   0             40007          180000.0               4336
# 3                   1             88268          225000.0              37943
# 4                   0             88268          144000.0              37943
#
#    OCCUPATION_TYPE  OWN_CAR_AGE_0.0  OWN_CAR_AGE_1.0  OWN_CAR_AGE_2.0  \
# 0              NaN            False            False            False
# 1              NaN            False            False            False
# 2              NaN            False            False            False
# 3              NaN            False            False            False
# 4              NaN            False            False            False
#
#    OWN_CAR_AGE_3.0  OWN_CAR_AGE_4.0  ...  EXT_SOURCE_3 DAYS_BIRTH^2  \
# 0            False            False  ...               7.873642e+07
# 1            False            False  ...               1.722172e+08
# 2            False            False  ...               9.020156e+07
# 3            False            False  ...               2.738226e+07
# 4            False            False  ...               6.998141e+07
#
#    DAYS_BIRTH^3  AMT_CREDIT  AMT_ANNUITY  DAYS_EMPLOYED  DEF_OBS  \
# 0 -1.775077e+12    961146.0      28233.0        -2372.0      0.0
# 1 -5.742070e+12    296280.0      16069.5        -1712.0      0.0
# 2 -3.526384e+12    183694.5      11236.5         -553.0      0.0
# 3 -1.411335e+12    450000.0      22500.0        -1438.0      0.0
# 4 -1.487400e+12    545040.0      26640.0        -2362.0      0.0
#
#    CREDIT_INCOME_PERCENT  ANNUITY_INCOME_PERCENT  CREDIT_TERM  \
# 0               6.674625                0.196063     0.029374
# 1               2.862609                0.155261     0.054238
# 2               1.020525                0.062425     0.061169
# 3               2.000000                0.100000     0.050000
# 4               3.785000                0.185000     0.048877
#
#    DAYS_EMPLOYED_PERCENT
# 0               0.195904
# 1               0.095605
# 2               0.036331
# 3               0.128198
# 4               0.206921
#
# [5 rows x 102 columns]

# %%
print("train_poly=", train_poly.shape)
print("train_fix=", train_fix.shape)

print("test_poly=",test_poly.shape)
print("test_fix=", test_fix.shape)
# Out:
# train_poly= (171202, 94)
# train_fix= (171202, 102)
# test_poly= (61500, 94)
# test_fix= (61500, 102)

# %% [markdown]
# Flag¶

# %%
train_fix["FLAG_MOBIL"] = train["FLAG_MOBIL"]
train_fix["FLAG_EMP_PHONE"] = train["FLAG_EMP_PHONE"]
train_fix["FLAG_WORK_PHONE"] = train["FLAG_WORK_PHONE"]
train_fix["FLAG_CONT_MOBILE"] = train["FLAG_CONT_MOBILE"]
train_fix["FLAG_EMAIL"] = train["FLAG_EMAIL"]

test_fix["FLAG_MOBIL"] = test["FLAG_MOBIL"]
test_fix["FLAG_EMP_PHONE"] = test["FLAG_EMP_PHONE"]
test_fix["FLAG_WORK_PHONE"] = test["FLAG_WORK_PHONE"]
test_fix["FLAG_CONT_MOBILE"] = test["FLAG_CONT_MOBILE"]
test_fix["FLAG_EMAIL"] = test["FLAG_EMAIL"]

# %%
train_fix
# Out:
#         NAME_CONTRACT_TYPE  NAME_INCOME_TYPE  AMT_INCOME_TOTAL  \
# 0                        0             88268          112500.0
# 1                        0             30895          225000.0
# 2                        0             12007           54000.0
# 3                        0             30895           67500.0
# 4                        0             40007          157500.0
# ...                    ...               ...               ...
# 171197                   0             88268           83250.0
# 171198                   0             88268          247500.0
# 171199                   0             12007          292500.0
# 171200                   0             40007          112500.0
# 171201                   0             88268          108000.0
#
#         ORGANIZATION_TYPE  OCCUPATION_TYPE  OWN_CAR_AGE_0.0  OWN_CAR_AGE_1.0  \
# 0                    4991              NaN            False            False
# 1                   30898              NaN            False            False
# 2                    1185              NaN            False            False
# 3                   30898              NaN            False            False
# 4                   37943              NaN            False            False
# ...                   ...              ...              ...              ...
# 171197               1338              NaN            False            False
# 171198               1833              NaN            False             True
# 171199               4991              NaN            False            False
# 171200              37943              NaN            False            False
# 171201               3866              NaN            False            False
#
#         OWN_CAR_AGE_2.0  OWN_CAR_AGE_3.0  OWN_CAR_AGE_4.0  ...  DEF_OBS  \
# 0                 False            False            False  ...      NaN
# 1                 False            False            False  ...      NaN
# 2                 False            False            False  ...      0.0
# 3                 False            False            False  ...      NaN
# 4                 False            False            False  ...      NaN
# ...                 ...              ...              ...  ...      ...
# 171197            False            False            False  ...      NaN
# 171198            False            False            False  ...      NaN
# 171199            False            False            False  ...      0.5
# 171200            False            False            False  ...      NaN
# 171201            False            False            False  ...      NaN
#
#         CREDIT_INCOME_PERCENT  ANNUITY_INCOME_PERCENT  CREDIT_TERM  \
# 0                    6.712800                0.322920     0.048105
# 1                    2.600000                0.075080     0.028877
# 2                    6.188000                0.338083     0.054635
# 3                    2.264000                0.131867     0.058245
# 4                    1.721057                0.136800     0.079486
# ...                       ...                     ...          ...
# 171197               4.856757                0.249514     0.051375
# 171198               2.430182                0.117436     0.048324
# 171199               4.231400                0.168262     0.039765
# 171200               2.132000                0.223880     0.105009
# 171201               1.497500                0.079583     0.053144
#
#         DAYS_EMPLOYED_PERCENT  FLAG_MOBIL  FLAG_EMP_PHONE  FLAG_WORK_PHONE  \
# 0                    0.095094           1               1                1
# 1                         NaN           1               0                0
# 2                    0.028276           1               1                1
# 3                         NaN           1               0                0
# 4                    0.065232           1               1                1
# ...                       ...         ...             ...              ...
# 171197               0.149009           1               1                1
# 171198               0.005842           1               1                0
# 171199               0.229440           1               1                0
# 171200               0.019400           1               1                0
# 171201               0.290600           1               1                1
#
#         FLAG_CONT_MOBILE  FLAG_EMAIL
# 0                      1           0
# 1                      1           0
# 2                      1           0
# 3                      1           0
# 4                      1           0
# ...                  ...         ...
# 171197                 1           0
# 171198                 1           0
# 171199                 1           1
# 171200                 1           0
# 171201                 1           0
#
# [171202 rows x 107 columns]

# %%
#from sklearn.ensemble import RandomForestRegressor
import lightgbm as lgb
from sklearn.feature_selection import RFE

# 特徴選択器の作成
model = lgb.LGBMRegressor(
    metric='auc',
    random_state = 42,
)

rfe = RFE(estimator=model, n_features_to_select=30)

# 交差項を含むケースで特徴選択の実行と選択された特徴量のデータフレームを作成
rfe.fit(train_fix.values, train["TARGET"].values)# 全特徴量を使用する場合
X_rfe = train_fix.loc[:, rfe.support_]


# 選択された特徴量の数の確認
print("選択された特徴量の数: {}".format(X_rfe.shape[1]))

# 選択された特徴量の表示
X_rfe.head()
# Out:
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.091170 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 11157
# [LightGBM] [Info] Number of data points in the train set: 171202, number of used features: 96
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.162783 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 11157
# [LightGBM] [Info] Number of data points in the train set: 171202, number of used features: 96
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.125341 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 11157
# [LightGBM] [Info] Number of data points in the train set: 171202, number of used features: 96
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.166364 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 11157
# [LightGBM] [Info] Number of data points in the train set: 171202, number of used features: 96
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.073079 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 11157
# [LightGBM] [Info] Number of data points in the train set: 171202, number of used features: 96
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.165808 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 11155
# [LightGBM] [Info] Number of data points in the train set: 171202, number of used features: 95
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.072296 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 11155
# [LightGBM] [Info] Number of data points in the train set: 171202, number of used features: 95
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.279386 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 11153
# [LightGBM] [Info] Number of data points in the train set: 171202, number of used features: 94
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.163961 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 11153
# [LightGBM] [Info] Number of data points in the train set: 171202, number of used features: 94
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.163609 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 11153
# [LightGBM] [Info] Number of data points in the train set: 171202, number of used features: 94
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.072220 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 11153
# [LightGBM] [Info] Number of data points in the train set: 171202, number of used features: 94
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.096614 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 11151
# [LightGBM] [Info] Number of data points in the train set: 171202, number of used features: 93
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.070579 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 11149
# [LightGBM] [Info] Number of data points in the train set: 171202, number of used features: 92
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.110208 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 11149
# [LightGBM] [Info] Number of data points in the train set: 171202, number of used features: 92
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.069537 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 10894
# [LightGBM] [Info] Number of data points in the train set: 171202, number of used features: 91
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.154976 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 10639
# [LightGBM] [Info] Number of data points in the train set: 171202, number of used features: 90
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.154391 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 10637
# [LightGBM] [Info] Number of data points in the train set: 171202, number of used features: 89
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.067929 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 10635
# [LightGBM] [Info] Number of data points in the train set: 171202, number of used features: 88
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.067491 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 10633
# [LightGBM] [Info] Number of data points in the train set: 171202, number of used features: 87
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.065836 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 10378
# [LightGBM] [Info] Number of data points in the train set: 171202, number of used features: 86
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.231449 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 10123
# [LightGBM] [Info] Number of data points in the train set: 171202, number of used features: 85
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.150000 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 9868
# [LightGBM] [Info] Number of data points in the train set: 171202, number of used features: 84
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.155370 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 9866
# [LightGBM] [Info] Number of data points in the train set: 171202, number of used features: 83
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.149414 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 9864
# [LightGBM] [Info] Number of data points in the train set: 171202, number of used features: 82
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.143193 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 9609
# [LightGBM] [Info] Number of data points in the train set: 171202, number of used features: 81
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.101759 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 9607
# [LightGBM] [Info] Number of data points in the train set: 171202, number of used features: 80
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.146486 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 9605
# [LightGBM] [Info] Number of data points in the train set: 171202, number of used features: 79
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.097613 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 9603
# [LightGBM] [Info] Number of data points in the train set: 171202, number of used features: 78
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.139370 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 9601
# [LightGBM] [Info] Number of data points in the train set: 171202, number of used features: 77
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.143032 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 9599
# [LightGBM] [Info] Number of data points in the train set: 171202, number of used features: 76
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.149819 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 9597
# [LightGBM] [Info] Number of data points in the train set: 171202, number of used features: 75
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.135308 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 9595
# [LightGBM] [Info] Number of data points in the train set: 171202, number of used features: 74
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.214670 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 9593
# [LightGBM] [Info] Number of data points in the train set: 171202, number of used features: 73
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.137476 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 9589
# [LightGBM] [Info] Number of data points in the train set: 171202, number of used features: 71
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.130038 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 9334
# [LightGBM] [Info] Number of data points in the train set: 171202, number of used features: 70
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.130171 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 9079
# [LightGBM] [Info] Number of data points in the train set: 171202, number of used features: 69
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.209052 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 9077
# [LightGBM] [Info] Number of data points in the train set: 171202, number of used features: 68
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.126015 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 9075
# [LightGBM] [Info] Number of data points in the train set: 171202, number of used features: 67
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.126579 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 9073
# [LightGBM] [Info] Number of data points in the train set: 171202, number of used features: 66
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.120918 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 9071
# [LightGBM] [Info] Number of data points in the train set: 171202, number of used features: 65
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.123608 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 9071
# [LightGBM] [Info] Number of data points in the train set: 171202, number of used features: 65
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.195174 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 9069
# [LightGBM] [Info] Number of data points in the train set: 171202, number of used features: 64
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.122111 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 9067
# [LightGBM] [Info] Number of data points in the train set: 171202, number of used features: 63
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.120909 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 9067
# [LightGBM] [Info] Number of data points in the train set: 171202, number of used features: 63
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.121666 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 9065
# [LightGBM] [Info] Number of data points in the train set: 171202, number of used features: 62
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.121480 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 9063
# [LightGBM] [Info] Number of data points in the train set: 171202, number of used features: 61
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.207152 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 9061
# [LightGBM] [Info] Number of data points in the train set: 171202, number of used features: 60
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.055960 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 9059
# [LightGBM] [Info] Number of data points in the train set: 171202, number of used features: 59
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.121190 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 9057
# [LightGBM] [Info] Number of data points in the train set: 171202, number of used features: 58
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.066954 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 9055
# [LightGBM] [Info] Number of data points in the train set: 171202, number of used features: 57
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.114586 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 9053
# [LightGBM] [Info] Number of data points in the train set: 171202, number of used features: 56
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.114659 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 9051
# [LightGBM] [Info] Number of data points in the train set: 171202, number of used features: 55
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.193301 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 9049
# [LightGBM] [Info] Number of data points in the train set: 171202, number of used features: 54
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.113793 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 9047
# [LightGBM] [Info] Number of data points in the train set: 171202, number of used features: 53
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.037584 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 9045
# [LightGBM] [Info] Number of data points in the train set: 171202, number of used features: 52
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.111958 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 9043
# [LightGBM] [Info] Number of data points in the train set: 171202, number of used features: 51
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.097182 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 9041
# [LightGBM] [Info] Number of data points in the train set: 171202, number of used features: 50
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.148266 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 9039
# [LightGBM] [Info] Number of data points in the train set: 171202, number of used features: 49
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.091090 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 9037
# [LightGBM] [Info] Number of data points in the train set: 171202, number of used features: 48
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.092197 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 9035
# [LightGBM] [Info] Number of data points in the train set: 171202, number of used features: 47
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.146276 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 9033
# [LightGBM] [Info] Number of data points in the train set: 171202, number of used features: 46
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.086199 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 9031
# [LightGBM] [Info] Number of data points in the train set: 171202, number of used features: 45
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.086227 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 9029
# [LightGBM] [Info] Number of data points in the train set: 171202, number of used features: 44
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.081604 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 9027
# [LightGBM] [Info] Number of data points in the train set: 171202, number of used features: 43
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.082538 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 9025
# [LightGBM] [Info] Number of data points in the train set: 171202, number of used features: 42
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.127838 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 9023
# [LightGBM] [Info] Number of data points in the train set: 171202, number of used features: 41
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.078930 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 9021
# [LightGBM] [Info] Number of data points in the train set: 171202, number of used features: 40
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.075598 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 9019
# [LightGBM] [Info] Number of data points in the train set: 171202, number of used features: 39
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.119058 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 9017
# [LightGBM] [Info] Number of data points in the train set: 171202, number of used features: 38
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.117233 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 8762
# [LightGBM] [Info] Number of data points in the train set: 171202, number of used features: 37
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.075617 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 8754
# [LightGBM] [Info] Number of data points in the train set: 171202, number of used features: 36
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.114329 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 8499
# [LightGBM] [Info] Number of data points in the train set: 171202, number of used features: 35
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.062456 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 8244
# [LightGBM] [Info] Number of data points in the train set: 171202, number of used features: 34
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.059999 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7989
# [LightGBM] [Info] Number of data points in the train set: 171202, number of used features: 33
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.102233 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7734
# [LightGBM] [Info] Number of data points in the train set: 171202, number of used features: 32
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.053720 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7479
# [LightGBM] [Info] Number of data points in the train set: 171202, number of used features: 31
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.050922 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7224
# [LightGBM] [Info] Number of data points in the train set: 171202, number of used features: 30
# [LightGBM] [Info] Start training from score 0.080729
# 選択された特徴量の数: 30
#    AMT_INCOME_TOTAL  ORGANIZATION_TYPE  SK_ID_CURR  EXT_SOURCE_1  \
# 0          112500.0               4991           0      0.505858
# 1          225000.0              30898           1      0.505858
# 2           54000.0               1185           2      0.505858
# 3           67500.0              30898           3      0.505858
# 4          157500.0              37943           4      0.342344
#
#    EXT_SOURCE_2  EXT_SOURCE_3  DAYS_BIRTH  EXT_SOURCE_1 EXT_SOURCE_2  \
# 0      0.372591      0.537070        9233                   0.188478
# 1      0.449567      0.553165       20148                   0.227417
# 2      0.569503      0.537070       18496                   0.288088
# 3      0.105235      0.767523       24177                   0.053234
# 4      0.202490      0.669057       10685                   0.069321
#
#    EXT_SOURCE_1^2 EXT_SOURCE_2  EXT_SOURCE_1^2 EXT_SOURCE_3  ...  \
# 0                     0.095343                     0.137432  ...
# 1                     0.115041                     0.141550  ...
# 2                     0.145731                     0.137432  ...
# 3                     0.026929                     0.196403  ...
# 4                     0.023732                     0.078413  ...
#
#    EXT_SOURCE_2 DAYS_BIRTH^2  EXT_SOURCE_3 DAYS_BIRTH^2  AMT_CREDIT  \
# 0               3.176272e+07               4.578429e+07    755190.0
# 1               1.824981e+08               2.245527e+08    585000.0
# 2               1.948282e+08               1.837327e+08    334152.0
# 3               6.151249e+07               4.486382e+08    152820.0
# 4               2.311809e+07               7.638568e+07    271066.5
#
#    AMT_ANNUITY  DAYS_EMPLOYED  DEF_OBS  CREDIT_INCOME_PERCENT  \
# 0      36328.5          878.0      NaN               6.712800
# 1      16893.0            NaN      NaN               2.600000
# 2      18256.5          523.0      0.0               6.188000
# 3       8901.0            NaN      NaN               2.264000
# 4      21546.0          697.0      NaN               1.721057
#
#    ANNUITY_INCOME_PERCENT  CREDIT_TERM  DAYS_EMPLOYED_PERCENT
# 0                0.322920     0.048105               0.095094
# 1                0.075080     0.028877                    NaN
# 2                0.338083     0.054635               0.028276
# 3                0.131867     0.058245                    NaN
# 4                0.136800     0.079486               0.065232
#
# [5 rows x 30 columns]

# %%
import lightgbm as lgb
from sklearn.feature_selection import RFE

# 選択された特徴量の重要度を取得
selected_importances = rfe.estimator_.feature_importances_

# 選択された特徴量名を取得
selected_features = X_rfe.columns

# すべての特徴量の重要度を取得
#all_importances = RandomForestRegressor(random_state=42).fit(X_pf_df, y).feature_importances_

# すべての特徴量の名前を取得
#all_features = X_pf_df.columns
all_features = train_fix.columns

# 選択された特徴量の重要度と特徴量名を並べ替え
sorted_indices = np.argsort(selected_importances)[::-1]
sorted_selected_importances = selected_importances[sorted_indices]
sorted_selected_features = selected_features[sorted_indices]

# 特徴量重要度の比較プロット
plt.figure(figsize=(12, 8))

# 選択された特徴量の重要度のプロット
plt.subplot(2, 1, 1)
plt.title("Feature Importances after RFE")
plt.bar(range(len(sorted_selected_importances)), sorted_selected_importances, align="center")
plt.xticks(range(len(sorted_selected_importances)), sorted_selected_features, rotation=90)
plt.xlim([-1, len(sorted_selected_importances)])
plt.xlabel('Features')
plt.ylabel('Importance')

# すべての特徴量の重要度のプロット（上位10個）
#indices = np.argsort(all_importances)[::-1][:10]
#plt.subplot(2, 1, 2)
#plt.title("Top 10 Feature Importances")
#plt.bar(range(len(indices)), all_importances[indices], align="center")
#plt.xticks(range(len(indices)), np.array(all_features)[indices], rotation=90)
#plt.xlim([-1, len(indices)])
#plt.xlabel('Features')
#plt.ylabel('Importance')

plt.tight_layout()
plt.show()

# %%
#use_features = ["NAME_CONTRACT_TYPE","NAME_INCOME_TYPE","AMT_INCOME_TOTAL", "OWN_CAR_AGE", "ORGANIZATION_TYPE","OCCUPATION_TYPE"]
use_features = sorted_selected_features

target = train["TARGET"].values
train_fix2 = train_fix[use_features]
train_fix2["TARGET"] = target

test_fix2 = test_fix[use_features]

# %%
train_fix2
# Out:
#         CREDIT_TERM  DAYS_EMPLOYED_PERCENT  AMT_ANNUITY  SK_ID_CURR  \
# 0          0.048105               0.095094      36328.5           0
# 1          0.028877                    NaN      16893.0           1
# 2          0.054635               0.028276      18256.5           2
# 3          0.058245                    NaN       8901.0           3
# 4          0.079486               0.065232      21546.0           4
# ...             ...                    ...          ...         ...
# 171197     0.051375               0.149009      20772.0      171197
# 171198     0.048324               0.005842      29065.5      171198
# 171199     0.039765               0.229440      49216.5      171199
# 171200     0.105009               0.019400      25186.5      171200
# 171201     0.053144               0.290600       8595.0      171201
#
#         AMT_CREDIT  DAYS_BIRTH  EXT_SOURCE_1 EXT_SOURCE_2 EXT_SOURCE_3  \
# 0         755190.0        9233                                0.101226
# 1         585000.0       20148                                0.125799
# 2         334152.0       18496                                0.154723
# 3         152820.0       24177                                0.040858
# 4         271066.5       10685                                0.046380
# ...            ...         ...                                     ...
# 171197    404325.0       20529                                0.157336
# 171198    601470.0       22083                                0.165329
# 171199   1237684.5       11053                                0.254853
# 171200    239850.0        8505                                0.071031
# 171201    161730.0       17925                                0.100226
#
#         DAYS_EMPLOYED  CREDIT_INCOME_PERCENT  EXT_SOURCE_3  ...  EXT_SOURCE_2  \
# 0               878.0               6.712800      0.537070  ...      0.372591
# 1                 NaN               2.600000      0.553165  ...      0.449567
# 2               523.0               6.188000      0.537070  ...      0.569503
# 3                 NaN               2.264000      0.767523  ...      0.105235
# 4               697.0               1.721057      0.669057  ...      0.202490
# ...               ...                    ...           ...  ...           ...
# 171197         3059.0               4.856757      0.768808  ...      0.404560
# 171198          129.0               2.430182      0.537070  ...      0.608542
# 171199         2536.0               4.231400      0.758393  ...      0.664305
# 171200          165.0               2.132000      0.537070  ...      0.627050
# 171201         5209.0               1.497500      0.382502  ...      0.517986
#
#         EXT_SOURCE_2^2 EXT_SOURCE_3  EXT_SOURCE_1 EXT_SOURCE_3 DAYS_BIRTH  \
# 0                          0.074558                           2508.430048
# 1                          0.111800                           5637.865335
# 2                          0.174190                           5025.010524
# 3                          0.008500                           9386.899481
# 4                          0.027433                           2447.372552
# ...                             ...                                   ...
# 171197                     0.125830                           7983.875320
# 171198                     0.198889                           5999.530028
# 171199                     0.334680                           4240.360889
# 171200                     0.211171                            963.427073
# 171201                     0.102629                           3468.334303
#
#         EXT_SOURCE_1 EXT_SOURCE_3^2  EXT_SOURCE_1^2 DAYS_BIRTH  \
# 0                          0.145912                2362.650233
# 1                          0.154788                5155.710701
# 2                          0.145912                4732.977225
# 3                          0.297997                6186.699306
# 4                          0.153246                1252.275263
# ...                             ...                        ...
# 171197                     0.298995                5253.205528
# 171198                     0.145912                5650.861595
# 171199                     0.290949                2828.373555
# 171200                     0.060838                 378.356897
# 171201                     0.074011                4586.862930
#
#         EXT_SOURCE_1 EXT_SOURCE_2^2  EXT_SOURCE_1^2 EXT_SOURCE_2  \
# 0                          0.070225                     0.095343
# 1                          0.102239                     0.115041
# 2                          0.164067                     0.145731
# 3                          0.005602                     0.026929
# 4                          0.014037                     0.023732
# ...                             ...                          ...
# 171197                     0.082793                     0.103524
# 171198                     0.187331                     0.155721
# 171199                     0.223236                     0.169990
# 171200                     0.082931                     0.027895
# 171201                     0.135726                     0.132548
#
#         EXT_SOURCE_1 EXT_SOURCE_2 DAYS_BIRTH  EXT_SOURCE_1 EXT_SOURCE_2  \
# 0                                1740.215731                   0.188478
# 1                                4581.994743                   0.227417
# 2                                5328.468440                   0.288088
# 3                                1287.031594                   0.053234
# 4                                 740.696248                   0.069321
# ...                                      ...                        ...
# 171197                           4201.251387                   0.204650
# 171198                           6797.929260                   0.307835
# 171199                           3714.291728                   0.336044
# 171200                           1124.838200                   0.132256
# 171201                           4696.834002                   0.262027
#
#         TARGET
# 0            0
# 1            0
# 2            0
# 3            0
# 4            1
# ...        ...
# 171197       0
# 171198       0
# 171199       0
# 171200       0
# 171201       0
#
# [171202 rows x 31 columns]

# %%
test_fix2
# Out:
#        CREDIT_TERM  DAYS_EMPLOYED_PERCENT  AMT_ANNUITY  SK_ID_CURR  \
# 0         0.029374               0.195904      28233.0      171202
# 1         0.054238               0.095605      16069.5      171203
# 2         0.061169               0.036331      11236.5      171204
# 3         0.050000               0.128198      22500.0      171205
# 4         0.048877               0.206921      26640.0      171206
# ...            ...                    ...          ...         ...
# 61495     0.029340               0.069291      37800.0      232697
# 61496     0.056308               0.048833      15408.0      232698
# 61497     0.091719               0.049742      26725.5      232699
# 61498     0.079185               0.517678      59094.0      232700
# 61499     0.028884               0.285845      16429.5      232701
#
#        AMT_CREDIT  DAYS_BIRTH  EXT_SOURCE_1 EXT_SOURCE_2 EXT_SOURCE_3  \
# 0        961146.0      -12108                                0.195723
# 1        296280.0      -17907                                0.078056
# 2        183694.5      -15221                                0.069416
# 3        450000.0      -11217                                0.051784
# 4        545040.0      -11415                                0.054094
# ...           ...         ...                                     ...
# 61495   1288350.0      -11430                                0.001475
# 61496    273636.0      -17181                                0.147029
# 61497    291384.0      -14515                                0.157333
# 61498    746280.0      -16914                                0.043018
# 61499    568800.0       -9799                                0.054629
#
#        DAYS_EMPLOYED  CREDIT_INCOME_PERCENT  EXT_SOURCE_3  ...  \
# 0            -2372.0               6.674625      0.537070  ...
# 1            -1712.0               2.862609      0.537070  ...
# 2             -553.0               1.020525      0.389339  ...
# 3            -1438.0               2.000000      0.217629  ...
# 4            -2362.0               3.785000      0.537070  ...
# ...              ...                    ...           ...  ...
# 61495         -792.0               4.090000      0.307737  ...
# 61496         -839.0               3.040400      0.434733  ...
# 61497         -722.0               2.023500      0.537070  ...
# 61498        -8756.0               3.856744      0.537070  ...
# 61499        -2801.0               4.213333      0.399676  ...
#
#        EXT_SOURCE_2 DAYS_BIRTH^2  EXT_SOURCE_2  EXT_SOURCE_2^2 EXT_SOURCE_3  \
# 0                   1.056156e+08      0.720416                     0.278739
# 1                   9.212781e+07      0.287306                     0.044332
# 2                   8.165659e+07      0.352456                     0.048366
# 3                   5.918425e+07      0.470384                     0.048153
# 4                   4.862002e+07      0.373133                     0.074775
# ...                          ...           ...                          ...
# 61495               2.374126e+06      0.018172                     0.000102
# 61496               1.973553e+08      0.668578                     0.194324
# 61497               1.209651e+08      0.574151                     0.177045
# 61498               6.485906e+07      0.226714                     0.027605
# 61499               2.594506e+07      0.270204                     0.029180
#
#        EXT_SOURCE_1 EXT_SOURCE_3 DAYS_BIRTH  EXT_SOURCE_1 EXT_SOURCE_3^2  \
# 0                              -3289.512729                     0.145912
# 1                              -4864.990455                     0.145912
# 2                              -2997.775886                     0.076680
# 3                              -1234.868829                     0.023959
# 4                              -1654.853077                     0.077860
# ...                                     ...                          ...
# 61495                           -927.470526                     0.024971
# 61496                          -3778.327449                     0.095604
# 61497                          -3977.506607                     0.147172
# 61498                          -3209.336464                     0.101906
# 61499                          -1981.151599                     0.080806
#
#        EXT_SOURCE_1^2 DAYS_BIRTH  EXT_SOURCE_1 EXT_SOURCE_2^2  \
# 0                   -3098.339546                     0.262539
# 1                   -4582.256875                     0.041756
# 2                   -3894.931139                     0.062840
# 3                   -2870.339832                     0.111927
# 4                    -831.727857                     0.037582
# ...                          ...                          ...
# 61495                -794.685757                     0.000087
# 61496               -4396.479331                     0.226117
# 61497               -3778.705618                     0.168196
# 61498               -2111.166349                     0.018159
# 61499               -2507.485068                     0.036933
#
#        EXT_SOURCE_1^2 EXT_SOURCE_2  EXT_SOURCE_1 EXT_SOURCE_2 DAYS_BIRTH  \
# 0                         0.184349                          -4412.490767
# 1                         0.073519                          -2602.532845
# 2                         0.090191                          -2713.790647
# 3                         0.120368                          -2669.056073
# 4                         0.027187                          -1149.719413
# ...                            ...                                   ...
# 61495                     0.001263                            -54.768656
# 61496                     0.171084                          -5810.703991
# 61497                     0.149469                          -4252.123911
# 61498                     0.028298                          -1354.760101
# 61499                     0.069143                          -1339.371949
#
#        EXT_SOURCE_1 EXT_SOURCE_2
# 0                       0.364428
# 1                       0.145336
# 2                       0.178293
# 3                       0.237947
# 4                       0.100720
# ...                          ...
# 61495                   0.004792
# 61496                   0.338205
# 61497                   0.292947
# 61498                   0.080097
# 61499                   0.136685
#
# [61500 rows x 30 columns]

# %% [markdown]
# ## 3. 機械学習モデルの作成
# ここでは、機械学習モデルの作成を行います。

# %% [markdown]
# まずは、必要なライブラリを読み込みます。
#
# - train_test_split：データを訓練用データと評価用データに分割する。
# - StandardScaler：データを標準化する。
# - roc_auc_score：今回の評価指標であるAUCを計算する。

# %%
# ライブラリの読み込み
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import roc_auc_score

# %% [markdown]
# # Make Predictions using Engineered Features
#
# The only way to see if the Polynomial Features and Domain knowledge improved the model is to train a test a model on these features! We can then compare the submission performance to that for the model without these features to gauge the effect of our feature engineering.

# %%
train_fix2.isnull().sum()
# Out:
# CREDIT_TERM                                   6
# DAYS_EMPLOYED_PERCENT                     30898
# AMT_ANNUITY                                   6
# SK_ID_CURR                                    0
# AMT_CREDIT                                    0
# DAYS_BIRTH                                    0
# EXT_SOURCE_1 EXT_SOURCE_2 EXT_SOURCE_3        0
# DAYS_EMPLOYED                             30898
# CREDIT_INCOME_PERCENT                         0
# EXT_SOURCE_3                                  0
# EXT_SOURCE_1                                  0
# ORGANIZATION_TYPE                             0
# EXT_SOURCE_1 DAYS_BIRTH^2                     0
# DEF_OBS                                   91906
# EXT_SOURCE_2 EXT_SOURCE_3 DAYS_BIRTH          0
# EXT_SOURCE_2 EXT_SOURCE_3^2                   0
# ANNUITY_INCOME_PERCENT                        6
# EXT_SOURCE_1^2 EXT_SOURCE_3                   0
# AMT_INCOME_TOTAL                              0
# EXT_SOURCE_3 DAYS_BIRTH^2                     0
# EXT_SOURCE_2 DAYS_BIRTH^2                     0
# EXT_SOURCE_2                                  0
# EXT_SOURCE_2^2 EXT_SOURCE_3                   0
# EXT_SOURCE_1 EXT_SOURCE_3 DAYS_BIRTH          0
# EXT_SOURCE_1 EXT_SOURCE_3^2                   0
# EXT_SOURCE_1^2 DAYS_BIRTH                     0
# EXT_SOURCE_1 EXT_SOURCE_2^2                   0
# EXT_SOURCE_1^2 EXT_SOURCE_2                   0
# EXT_SOURCE_1 EXT_SOURCE_2 DAYS_BIRTH          0
# EXT_SOURCE_1 EXT_SOURCE_2                     0
# TARGET                                        0
# dtype: int64

# %%
train_fix2
# Out:
#         CREDIT_TERM  DAYS_EMPLOYED_PERCENT  AMT_ANNUITY  SK_ID_CURR  \
# 0          0.048105               0.095094      36328.5           0
# 1          0.028877                    NaN      16893.0           1
# 2          0.054635               0.028276      18256.5           2
# 3          0.058245                    NaN       8901.0           3
# 4          0.079486               0.065232      21546.0           4
# ...             ...                    ...          ...         ...
# 171197     0.051375               0.149009      20772.0      171197
# 171198     0.048324               0.005842      29065.5      171198
# 171199     0.039765               0.229440      49216.5      171199
# 171200     0.105009               0.019400      25186.5      171200
# 171201     0.053144               0.290600       8595.0      171201
#
#         AMT_CREDIT  DAYS_BIRTH  EXT_SOURCE_1 EXT_SOURCE_2 EXT_SOURCE_3  \
# 0         755190.0        9233                                0.101226
# 1         585000.0       20148                                0.125799
# 2         334152.0       18496                                0.154723
# 3         152820.0       24177                                0.040858
# 4         271066.5       10685                                0.046380
# ...            ...         ...                                     ...
# 171197    404325.0       20529                                0.157336
# 171198    601470.0       22083                                0.165329
# 171199   1237684.5       11053                                0.254853
# 171200    239850.0        8505                                0.071031
# 171201    161730.0       17925                                0.100226
#
#         DAYS_EMPLOYED  CREDIT_INCOME_PERCENT  EXT_SOURCE_3  ...  EXT_SOURCE_2  \
# 0               878.0               6.712800      0.537070  ...      0.372591
# 1                 NaN               2.600000      0.553165  ...      0.449567
# 2               523.0               6.188000      0.537070  ...      0.569503
# 3                 NaN               2.264000      0.767523  ...      0.105235
# 4               697.0               1.721057      0.669057  ...      0.202490
# ...               ...                    ...           ...  ...           ...
# 171197         3059.0               4.856757      0.768808  ...      0.404560
# 171198          129.0               2.430182      0.537070  ...      0.608542
# 171199         2536.0               4.231400      0.758393  ...      0.664305
# 171200          165.0               2.132000      0.537070  ...      0.627050
# 171201         5209.0               1.497500      0.382502  ...      0.517986
#
#         EXT_SOURCE_2^2 EXT_SOURCE_3  EXT_SOURCE_1 EXT_SOURCE_3 DAYS_BIRTH  \
# 0                          0.074558                           2508.430048
# 1                          0.111800                           5637.865335
# 2                          0.174190                           5025.010524
# 3                          0.008500                           9386.899481
# 4                          0.027433                           2447.372552
# ...                             ...                                   ...
# 171197                     0.125830                           7983.875320
# 171198                     0.198889                           5999.530028
# 171199                     0.334680                           4240.360889
# 171200                     0.211171                            963.427073
# 171201                     0.102629                           3468.334303
#
#         EXT_SOURCE_1 EXT_SOURCE_3^2  EXT_SOURCE_1^2 DAYS_BIRTH  \
# 0                          0.145912                2362.650233
# 1                          0.154788                5155.710701
# 2                          0.145912                4732.977225
# 3                          0.297997                6186.699306
# 4                          0.153246                1252.275263
# ...                             ...                        ...
# 171197                     0.298995                5253.205528
# 171198                     0.145912                5650.861595
# 171199                     0.290949                2828.373555
# 171200                     0.060838                 378.356897
# 171201                     0.074011                4586.862930
#
#         EXT_SOURCE_1 EXT_SOURCE_2^2  EXT_SOURCE_1^2 EXT_SOURCE_2  \
# 0                          0.070225                     0.095343
# 1                          0.102239                     0.115041
# 2                          0.164067                     0.145731
# 3                          0.005602                     0.026929
# 4                          0.014037                     0.023732
# ...                             ...                          ...
# 171197                     0.082793                     0.103524
# 171198                     0.187331                     0.155721
# 171199                     0.223236                     0.169990
# 171200                     0.082931                     0.027895
# 171201                     0.135726                     0.132548
#
#         EXT_SOURCE_1 EXT_SOURCE_2 DAYS_BIRTH  EXT_SOURCE_1 EXT_SOURCE_2  \
# 0                                1740.215731                   0.188478
# 1                                4581.994743                   0.227417
# 2                                5328.468440                   0.288088
# 3                                1287.031594                   0.053234
# 4                                 740.696248                   0.069321
# ...                                      ...                        ...
# 171197                           4201.251387                   0.204650
# 171198                           6797.929260                   0.307835
# 171199                           3714.291728                   0.336044
# 171200                           1124.838200                   0.132256
# 171201                           4696.834002                   0.262027
#
#         TARGET
# 0            0
# 1            0
# 2            0
# 3            0
# 4            1
# ...        ...
# 171197       0
# 171198       0
# 171199       0
# 171200       0
# 171201       0
#
# [171202 rows x 31 columns]

# %%
test_fix2
# Out:
#        CREDIT_TERM  DAYS_EMPLOYED_PERCENT  AMT_ANNUITY  SK_ID_CURR  \
# 0         0.029374               0.195904      28233.0      171202
# 1         0.054238               0.095605      16069.5      171203
# 2         0.061169               0.036331      11236.5      171204
# 3         0.050000               0.128198      22500.0      171205
# 4         0.048877               0.206921      26640.0      171206
# ...            ...                    ...          ...         ...
# 61495     0.029340               0.069291      37800.0      232697
# 61496     0.056308               0.048833      15408.0      232698
# 61497     0.091719               0.049742      26725.5      232699
# 61498     0.079185               0.517678      59094.0      232700
# 61499     0.028884               0.285845      16429.5      232701
#
#        AMT_CREDIT  DAYS_BIRTH  EXT_SOURCE_1 EXT_SOURCE_2 EXT_SOURCE_3  \
# 0        961146.0      -12108                                0.195723
# 1        296280.0      -17907                                0.078056
# 2        183694.5      -15221                                0.069416
# 3        450000.0      -11217                                0.051784
# 4        545040.0      -11415                                0.054094
# ...           ...         ...                                     ...
# 61495   1288350.0      -11430                                0.001475
# 61496    273636.0      -17181                                0.147029
# 61497    291384.0      -14515                                0.157333
# 61498    746280.0      -16914                                0.043018
# 61499    568800.0       -9799                                0.054629
#
#        DAYS_EMPLOYED  CREDIT_INCOME_PERCENT  EXT_SOURCE_3  ...  \
# 0            -2372.0               6.674625      0.537070  ...
# 1            -1712.0               2.862609      0.537070  ...
# 2             -553.0               1.020525      0.389339  ...
# 3            -1438.0               2.000000      0.217629  ...
# 4            -2362.0               3.785000      0.537070  ...
# ...              ...                    ...           ...  ...
# 61495         -792.0               4.090000      0.307737  ...
# 61496         -839.0               3.040400      0.434733  ...
# 61497         -722.0               2.023500      0.537070  ...
# 61498        -8756.0               3.856744      0.537070  ...
# 61499        -2801.0               4.213333      0.399676  ...
#
#        EXT_SOURCE_2 DAYS_BIRTH^2  EXT_SOURCE_2  EXT_SOURCE_2^2 EXT_SOURCE_3  \
# 0                   1.056156e+08      0.720416                     0.278739
# 1                   9.212781e+07      0.287306                     0.044332
# 2                   8.165659e+07      0.352456                     0.048366
# 3                   5.918425e+07      0.470384                     0.048153
# 4                   4.862002e+07      0.373133                     0.074775
# ...                          ...           ...                          ...
# 61495               2.374126e+06      0.018172                     0.000102
# 61496               1.973553e+08      0.668578                     0.194324
# 61497               1.209651e+08      0.574151                     0.177045
# 61498               6.485906e+07      0.226714                     0.027605
# 61499               2.594506e+07      0.270204                     0.029180
#
#        EXT_SOURCE_1 EXT_SOURCE_3 DAYS_BIRTH  EXT_SOURCE_1 EXT_SOURCE_3^2  \
# 0                              -3289.512729                     0.145912
# 1                              -4864.990455                     0.145912
# 2                              -2997.775886                     0.076680
# 3                              -1234.868829                     0.023959
# 4                              -1654.853077                     0.077860
# ...                                     ...                          ...
# 61495                           -927.470526                     0.024971
# 61496                          -3778.327449                     0.095604
# 61497                          -3977.506607                     0.147172
# 61498                          -3209.336464                     0.101906
# 61499                          -1981.151599                     0.080806
#
#        EXT_SOURCE_1^2 DAYS_BIRTH  EXT_SOURCE_1 EXT_SOURCE_2^2  \
# 0                   -3098.339546                     0.262539
# 1                   -4582.256875                     0.041756
# 2                   -3894.931139                     0.062840
# 3                   -2870.339832                     0.111927
# 4                    -831.727857                     0.037582
# ...                          ...                          ...
# 61495                -794.685757                     0.000087
# 61496               -4396.479331                     0.226117
# 61497               -3778.705618                     0.168196
# 61498               -2111.166349                     0.018159
# 61499               -2507.485068                     0.036933
#
#        EXT_SOURCE_1^2 EXT_SOURCE_2  EXT_SOURCE_1 EXT_SOURCE_2 DAYS_BIRTH  \
# 0                         0.184349                          -4412.490767
# 1                         0.073519                          -2602.532845
# 2                         0.090191                          -2713.790647
# 3                         0.120368                          -2669.056073
# 4                         0.027187                          -1149.719413
# ...                            ...                                   ...
# 61495                     0.001263                            -54.768656
# 61496                     0.171084                          -5810.703991
# 61497                     0.149469                          -4252.123911
# 61498                     0.028298                          -1354.760101
# 61499                     0.069143                          -1339.371949
#
#        EXT_SOURCE_1 EXT_SOURCE_2
# 0                       0.364428
# 1                       0.145336
# 2                       0.178293
# 3                       0.237947
# 4                       0.100720
# ...                          ...
# 61495                   0.004792
# 61496                   0.338205
# 61497                   0.292947
# 61498                   0.080097
# 61499                   0.136685
#
# [61500 rows x 30 columns]

# %% [markdown]
# データを説明変数と目的変数に分割します。今回の目的変数は「TARGET」なので、それ以外が説明変数となります。

# %%
# 目的変数と説明変数に分割
#X = train_poly.drop("TARGET", axis=1).values
# = train_poly["TARGET"].values
#X = train_fix2.values
X = train_fix2.drop("TARGET", axis=1).values
y = train["TARGET"].values
X_test = test_fix2.values
X
# Out:
# array([[4.81051126e-02, 9.50936857e-02, 3.63285000e+04, ...,
#         9.53429431e-02, 1.74021573e+03, 1.88477822e-01],
#        [2.88769231e-02,            nan, 1.68930000e+04, ...,
#         1.15040548e-01, 4.58199474e+03, 2.27416852e-01],
#        [5.46353157e-02, 2.82763841e-02, 1.82565000e+04, ...,
#         1.45731314e-01, 5.32846844e+03, 2.88087610e-01],
#        ...,
#        [3.97649805e-02, 2.29439971e-01, 4.92165000e+04, ...,
#         1.69990300e-01, 3.71429173e+03, 3.36043764e-01],
#        [1.05009381e-01, 1.94003527e-02, 2.51865000e+04, ...,
#         2.78951954e-02, 1.12483820e+03, 1.32256108e-01],
#        [5.31441291e-02, 2.90599721e-01, 8.59500000e+03, ...,
#         1.32548356e-01, 4.69683400e+03, 2.62027002e-01]])

# %% [markdown]
# データを標準化します。標準化とは、平均が0で分散が1となるように値を変換する操作です。ロジスティック回帰やニューラルネットワークなどの一部のモデルでは、このように値のスケールを揃えないと学習が上手くいきません。

# %%
# 標準化
#sc = StandardScaler()
#sc.fit(X)
#X_std = sc.transform(X)
#X_test_std = sc.transform(X_test)

# %% [markdown]
# 学習用データのうち、7割を訓練データ、3割を評価データとして分割します。このように、学習データの一部を学習に用いずに、評価用として取っておく手法をホールドアウト法と呼びます。これにより、未知のデータに対する予測精度（汎化性能）を算出することが出来ます。

# %%
# 訓練データと評価データに分割
#X_train, X_valid, y_train, y_valid = train_test_split(X_std, y, test_size=0.3, stratify=y, random_state=0)
X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.3, stratify=y, random_state=0)

# %% [markdown]
# ロジスティック回帰と多層パーセプトロンでモデルを作成してみます。

# %%
#from catboost import CatBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier, RandomForestClassifier, HistGradientBoostingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier
from sklearn.ensemble import VotingClassifier

from sklearn.model_selection import cross_val_score
from sklearn import metrics

# 重回帰のモデル構築のためのインポート
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge

# %% [markdown]
# BaseLine_model =XGBoost

# %%
# LogisticRegression
#from sklearn.linear_model import LogisticRegression

#lr = LogisticRegression(random_state=0)
#lr.fit(X_train, y_train)

#lr_train_pred = lr.predict_proba(X_train)[:, 1]
#lr_valid_pred = lr.predict_proba(X_valid)[:, 1]
#print(f"Train Score: {roc_auc_score(y_train, lr_train_pred)}")
#print(f"Valid Score: {roc_auc_score(y_valid, lr_valid_pred)}")

# %%
# MLPClassifier
#from sklearn.neural_network import MLPClassifier

#mlp = MLPClassifier(random_state=0)
#mlp.fit(X_train, y_train)

#mlp_train_pred = mlp.predict_proba(X_train)[:, 1]
#mlp_valid_pred = mlp.predict_proba(X_valid)[:, 1]
#print(f"Train Score: {roc_auc_score(y_train, mlp_train_pred)}")
#print(f"Valid Score: {roc_auc_score(y_valid, mlp_valid_pred)}")

# %% [markdown]
# つぎに、勾配ブースティング木（GBDT）と呼ばれるモデルを作成してみたいと思います。GBDTは、使いやすさと精度の高さから、Kaggleなどの分析コンペでよく使用されているモデルです。GBDTの特徴として以下のような点が挙げられます。
# - 欠損値のあるデータを学習できる。
# - 標準化などの値のスケーリングが不要。
# - 精度が高い。
# - 特徴量間の相互作用が反映される。
# - 特徴量が多くても精度が落ちにくく、速度が速い。
#
# 今回はGBDTの中でも代表的なxgboostとlightgbmを扱います。

# %%
# XGBClassifier
from xgboost import XGBClassifier

xgb = XGBClassifier(random_state=0)
#xgb.fit(X_train, y_train)

#xgb_train_pred = xgb.predict_proba(X_train)[:, 1]
#xgb_valid_pred = xgb.predict_proba(X_valid)[:, 1]
#print(f"Train Score: {roc_auc_score(y_train, xgb_train_pred)}")
#print(f"Valid Score: {roc_auc_score(y_valid, xgb_valid_pred)}")

# %%
#GBM
#from sklearn.ensemble import GradientBoostingClassifier

#gb = GradientBoostingClassifier(random_state=0)
#gb.fit(X_train, y_train)

#gb_train_pred = gb.predict_proba(X_train)[:, 1]
#gb_valid_pred = gb.predict_proba(X_valid)[:, 1]
#print(f"Train Score: {roc_auc_score(y_train, gb_train_pred)}")
#print(f"Valid Score: {roc_auc_score(y_valid, gb_valid_pred)}")

# %%
# LGBMClassifier
#from lightgbm import LGBMClassifier
#import lightgbm as lgb

#lgb = LGBMClassifier(random_state=0)

#lgb.fit(X_train, y_train)
#lgb_train_pred = lgb.predict_proba(X_train)[:, 1]
#lgb_valid_pred = lgb.predict_proba(X_valid)[:, 1]
#print(f"Train Score: {roc_auc_score(y_train, lgb_train_pred)}")
#print(f"Valid Score: {roc_auc_score(y_valid, lgb_valid_pred)}")

# %%
# LightGBMのインポート
#import lightgbm as lgb

# グリッドサーチのインポート
#from sklearn.model_selection import GridSearchCV

# パラメータの準備
#parameters = {
    #'max_depth': [6, 8, 10, 12, 15, 20, 30],
    #'min_data_in_leaf': [20, 25, 30, 35, 40, 45, 50, 55, 60],
    #'num_leaves': [20, 30, 40, 50, 60]
#    'max_depth': [6, 8, 10, 12],
#    'min_data_in_leaf': [20, 25, 30, ],
#    'num_leaves': [20, 30, 40, 60]

#}

# グリッドサーチの設定
#lgb = GridSearchCV(LGBMClassifier(random_state=42), parameters, cv=5, scoring='roc_auc', return_train_score=True)

# グリッドサーチの実行
#lgb.fit(X_train, y_train)

#lgb_train_pred = lgb.predict_proba(X_train)[:, 1]
#lgb_valid_pred = lgb.predict_proba(X_valid)[:, 1]

#print(f"Train Score: {roc_auc_score(y_train, lgb_train_pred)}")
#print(f"Valid Score: {roc_auc_score(y_valid, lgb_valid_pred)}")

# %% [markdown]
# ここまでで、4つのモデルを作成しました。ここでは、アンサンブルと呼ばれる複数のモデルを組み合わせることを行います。アンサンブルには、様々な手法がありますが、今回はシンプルに4つのモデルの平均値をとることにします。

# %%
#train_pred = (lr_train_pred + mlp_train_pred + lgb_train_pred + xgb_train_pred)/4
#valid_pred = (lr_valid_pred + mlp_valid_pred + lgb_valid_pred + xgb_valid_pred)/4

#train_pred = (lr_train_pred + lgb_train_pred + xgb_train_pred)/3
#valid_pred = (lr_valid_pred + lgb_valid_pred + xgb_valid_pred)/3

#train_pred = (lgb_train_pred + xgb_train_pred)/2
#valid_pred = (lgb_valid_pred + xgb_valid_pred)/2

#print(f"Train Score: {roc_auc_score(y_train, train_pred)}")
#print(f"Valid Score: {roc_auc_score(y_valid, valid_pred)}")

# %% [markdown]
# 今回は、アンサンブルをしても精度の向上には繋がらなかったため、最終的なモデルは一番スコアの高かったxgboostを用いることにします。
#
# やっぱり多様なModelを試してみる

# %%
# リッジ回帰用のクラス
# モデルの構築と評価
#linear = LinearRegression()
#ridge = Ridge(random_state=0)

#for model in [linear, ridge]:
#    model.fit(X_train, y_train)
#    print('{}(train):{:.6f}'.format(model.__class__.__name__ , model.score(X_train, y_train)))
#    print('{}(test):{:.6f}'.format(model.__class__.__name__ , model.score(X_valid, y_valid)))

# %%
# グリッドサーチのインポート
#from sklearn.model_selection import GridSearchCV
#
# パラメータの準備
#parameters = {
#    'max_depth': [6, 8, 10, 12, 15, 20, 30],
#    'min_data_in_leaf': [20, 25, 30, 35, 40, 45, 50, 55, 60],
#    'num_leaves': [20, 30, 40, 50, 60]
#}
#
# グリッドサーチの設定
#lgb_gcv = GridSearchCV(lgb, parameters, cv=5, scoring='roc_auc', return_train_score=True)

# グリッドサーチの実行
#lgb_gcv.fit(X_train, y_train)

# %% [markdown]
# LightGBM最適化

# %%
# !pip install optuna optuna-integration
# Out:
# Requirement already satisfied: optuna in /usr/local/lib/python3.10/dist-packages (3.6.1)
# Requirement already satisfied: optuna-integration in /usr/local/lib/python3.10/dist-packages (3.6.0)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (1.13.2)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.10/dist-packages (from optuna) (6.8.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from optuna) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (24.1)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (2.0.31)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from optuna) (4.66.4)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from optuna) (6.0.1)
# Requirement already satisfied: Mako in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (1.3.5)
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.3.0->optuna) (3.0.3)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from Mako->alembic>=1.5.0->optuna) (2.1.5)

# %%
import optuna
import optuna.integration.lightgbm as lgb_tune
#LightGBM のハイパーパラメータ
params = {
    # 二値分類問題
    'objective': 'binary',
    # AUC の最大化を目指す
    'metric': 'auc',
    # Fatal の場合出力
    'verbosity': -1,
}

# データセットを生成する
lgb_train = lgb_tune.Dataset(X_train, y_train)
lgb_valid = lgb_tune.Dataset(X_valid, y_valid, reference=lgb_train)
#
model_tune = lgb_tune.train(params, lgb_train, valid_sets=lgb_valid,
                  num_boost_round=250,  # 最大イテレーション回数指定
                  callbacks=[lgb_tune.early_stopping(100), lgb_tune.log_evaluation(period=100)]# ここが変わった
                 )
# Out:
# [I 2024-07-02 00:17:05,678] A new study created in memory with name: no-name-176c60cc-60ae-4dc0-983a-d9dba2b8a1c6
# feature_fraction, val_score: -inf:   0%|          | 0/7 [00:00<?, ?it/s]
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's auc: 0.741697
# feature_fraction, val_score: 0.742474:  14%|#4        | 1/7 [00:39<03:58, 39.70s/it][I 2024-07-02 00:17:45,385] Trial 0 finished with value: 0.7424738340419035 and parameters: {'feature_fraction': 0.8}. Best is trial 0 with value: 0.7424738340419035.
# feature_fraction, val_score: 0.742474:  14%|#4        | 1/7 [00:39<03:58, 39.70s/it]
# Early stopping, best iteration is:
# [78]	valid_0's auc: 0.742474
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's auc: 0.744675
# feature_fraction, val_score: 0.744931:  29%|##8       | 2/7 [00:43<01:34, 18.84s/it][I 2024-07-02 00:17:49,626] Trial 1 finished with value: 0.7449312423146286 and parameters: {'feature_fraction': 0.7}. Best is trial 1 with value: 0.7449312423146286.
# feature_fraction, val_score: 0.744931:  29%|##8       | 2/7 [00:43<01:34, 18.84s/it]
# Early stopping, best iteration is:
# [95]	valid_0's auc: 0.744931
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's auc: 0.742802
# feature_fraction, val_score: 0.744931:  43%|####2     | 3/7 [00:47<00:47, 11.81s/it][I 2024-07-02 00:17:53,079] Trial 2 finished with value: 0.7432667398505844 and parameters: {'feature_fraction': 0.5}. Best is trial 1 with value: 0.7449312423146286.
# feature_fraction, val_score: 0.744931:  43%|####2     | 3/7 [00:47<00:47, 11.81s/it]
# Early stopping, best iteration is:
# [67]	valid_0's auc: 0.743267
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's auc: 0.743834
# feature_fraction, val_score: 0.744931:  57%|#####7    | 4/7 [00:54<00:30, 10.09s/it][I 2024-07-02 00:18:00,515] Trial 3 finished with value: 0.7438549799827221 and parameters: {'feature_fraction': 0.8999999999999999}. Best is trial 1 with value: 0.7449312423146286.
# feature_fraction, val_score: 0.744931:  57%|#####7    | 4/7 [00:54<00:30, 10.09s/it]
# Early stopping, best iteration is:
# [63]	valid_0's auc: 0.743855
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's auc: 0.744753
# feature_fraction, val_score: 0.745250:  71%|#######1  | 5/7 [00:58<00:15,  7.81s/it][I 2024-07-02 00:18:04,292] Trial 4 finished with value: 0.7452503811045111 and parameters: {'feature_fraction': 0.4}. Best is trial 4 with value: 0.7452503811045111.
# feature_fraction, val_score: 0.745250:  71%|#######1  | 5/7 [00:58<00:15,  7.81s/it]
# [200]	valid_0's auc: 0.743011
# Early stopping, best iteration is:
# [110]	valid_0's auc: 0.74525
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's auc: 0.74395
# feature_fraction, val_score: 0.745250:  86%|########5 | 6/7 [01:05<00:07,  7.57s/it][I 2024-07-02 00:18:11,396] Trial 5 finished with value: 0.744026943799032 and parameters: {'feature_fraction': 1.0}. Best is trial 4 with value: 0.7452503811045111.
# feature_fraction, val_score: 0.745250:  86%|########5 | 6/7 [01:05<00:07,  7.57s/it]
# Early stopping, best iteration is:
# [98]	valid_0's auc: 0.744027
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's auc: 0.743947
# feature_fraction, val_score: 0.745250: 100%|##########| 7/7 [01:09<00:00,  6.43s/it][I 2024-07-02 00:18:15,463] Trial 6 finished with value: 0.7445131550467657 and parameters: {'feature_fraction': 0.6}. Best is trial 4 with value: 0.7452503811045111.
# feature_fraction, val_score: 0.745250: 100%|##########| 7/7 [01:09<00:00,  9.97s/it]
# Early stopping, best iteration is:
# [63]	valid_0's auc: 0.744513
# num_leaves, val_score: 0.745250:   0%|          | 0/20 [00:00<?, ?it/s]
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's auc: 0.734754
# num_leaves, val_score: 0.745250:   5%|5         | 1/20 [00:03<01:15,  3.97s/it][I 2024-07-02 00:18:19,445] Trial 7 finished with value: 0.7381897370972733 and parameters: {'num_leaves': 155}. Best is trial 7 with value: 0.7381897370972733.
# num_leaves, val_score: 0.745250:   5%|5         | 1/20 [00:03<01:15,  3.97s/it]
# Early stopping, best iteration is:
# [40]	valid_0's auc: 0.73819
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's auc: 0.732713
# num_leaves, val_score: 0.745250:  10%|#         | 2/20 [00:14<02:18,  7.67s/it][I 2024-07-02 00:18:29,713] Trial 8 finished with value: 0.7356989832973008 and parameters: {'num_leaves': 209}. Best is trial 7 with value: 0.7381897370972733.
# num_leaves, val_score: 0.745250:  10%|#         | 2/20 [00:14<02:18,  7.67s/it]
# Early stopping, best iteration is:
# [40]	valid_0's auc: 0.735699
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's auc: 0.734457
# num_leaves, val_score: 0.745250:  15%|#5        | 3/20 [00:18<01:41,  5.96s/it][I 2024-07-02 00:18:33,635] Trial 9 finished with value: 0.7389651183052309 and parameters: {'num_leaves': 149}. Best is trial 9 with value: 0.7389651183052309.
# num_leaves, val_score: 0.745250:  15%|#5        | 3/20 [00:18<01:41,  5.96s/it]
# Early stopping, best iteration is:
# [40]	valid_0's auc: 0.738965
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's auc: 0.741326
# num_leaves, val_score: 0.745250:  20%|##        | 4/20 [00:21<01:19,  4.96s/it][I 2024-07-02 00:18:37,065] Trial 10 finished with value: 0.7424950827160643 and parameters: {'num_leaves': 41}. Best is trial 10 with value: 0.7424950827160643.
# num_leaves, val_score: 0.745250:  20%|##        | 4/20 [00:21<01:19,  4.96s/it]
# Early stopping, best iteration is:
# [68]	valid_0's auc: 0.742495
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's auc: 0.7402
# [200]	valid_0's auc: 0.742884
# num_leaves, val_score: 0.745250:  25%|##5       | 5/20 [00:28<01:26,  5.74s/it][I 2024-07-02 00:18:44,186] Trial 11 finished with value: 0.7439639206248229 and parameters: {'num_leaves': 6}. Best is trial 11 with value: 0.7439639206248229.
# num_leaves, val_score: 0.745250:  25%|##5       | 5/20 [00:28<01:26,  5.74s/it]
# Did not meet early stopping. Best iteration is:
# [250]	valid_0's auc: 0.743964
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's auc: 0.731842
# num_leaves, val_score: 0.745250:  30%|###       | 6/20 [00:33<01:15,  5.42s/it][I 2024-07-02 00:18:48,999] Trial 12 finished with value: 0.7352370704793414 and parameters: {'num_leaves': 252}. Best is trial 11 with value: 0.7439639206248229.
# num_leaves, val_score: 0.745250:  30%|###       | 6/20 [00:33<01:15,  5.42s/it]
# Early stopping, best iteration is:
# [40]	valid_0's auc: 0.735237
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's auc: 0.740346
# num_leaves, val_score: 0.745250:  35%|###5      | 7/20 [00:37<01:04,  4.99s/it][I 2024-07-02 00:18:53,098] Trial 13 finished with value: 0.7416457972962818 and parameters: {'num_leaves': 78}. Best is trial 11 with value: 0.7439639206248229.
# num_leaves, val_score: 0.745250:  35%|###5      | 7/20 [00:37<01:04,  4.99s/it]
# Early stopping, best iteration is:
# [54]	valid_0's auc: 0.741646
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's auc: 0.73911
# num_leaves, val_score: 0.745250:  40%|####      | 8/20 [00:44<01:07,  5.59s/it][I 2024-07-02 00:18:59,979] Trial 14 finished with value: 0.7416637280202402 and parameters: {'num_leaves': 95}. Best is trial 11 with value: 0.7439639206248229.
# num_leaves, val_score: 0.745250:  40%|####      | 8/20 [00:44<01:07,  5.59s/it]
# Early stopping, best iteration is:
# [43]	valid_0's auc: 0.741664
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's auc: 0.732713
# num_leaves, val_score: 0.745250:  45%|####5     | 9/20 [00:48<00:57,  5.24s/it][I 2024-07-02 00:19:04,437] Trial 15 finished with value: 0.7356989832973008 and parameters: {'num_leaves': 209}. Best is trial 11 with value: 0.7439639206248229.
# num_leaves, val_score: 0.745250:  45%|####5     | 9/20 [00:48<00:57,  5.24s/it]
# Early stopping, best iteration is:
# [40]	valid_0's auc: 0.735699
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's auc: 0.738097
# num_leaves, val_score: 0.745250:  50%|#####     | 10/20 [00:55<00:57,  5.76s/it][I 2024-07-02 00:19:11,353] Trial 16 finished with value: 0.7398262681427893 and parameters: {'num_leaves': 103}. Best is trial 11 with value: 0.7439639206248229.
# num_leaves, val_score: 0.745250:  50%|#####     | 10/20 [00:55<00:57,  5.76s/it]
# Early stopping, best iteration is:
# [44]	valid_0's auc: 0.739826
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's auc: 0.734967
# num_leaves, val_score: 0.745250:  55%|#####5    | 11/20 [01:00<00:47,  5.32s/it][I 2024-07-02 00:19:15,687] Trial 17 finished with value: 0.7373790691440899 and parameters: {'num_leaves': 186}. Best is trial 11 with value: 0.7439639206248229.
# num_leaves, val_score: 0.745250:  55%|#####5    | 11/20 [01:00<00:47,  5.32s/it]
# Early stopping, best iteration is:
# [44]	valid_0's auc: 0.737379
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's auc: 0.730025
# num_leaves, val_score: 0.745250:  60%|######    | 12/20 [01:05<00:42,  5.30s/it][I 2024-07-02 00:19:20,953] Trial 18 finished with value: 0.7332645018305941 and parameters: {'num_leaves': 254}. Best is trial 11 with value: 0.7439639206248229.
# num_leaves, val_score: 0.745250:  60%|######    | 12/20 [01:05<00:42,  5.30s/it]
# Early stopping, best iteration is:
# [53]	valid_0's auc: 0.733265
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's auc: 0.736712
# [200]	valid_0's auc: 0.741664
# num_leaves, val_score: 0.745250:  65%|######5   | 13/20 [01:14<00:44,  6.36s/it][I 2024-07-02 00:19:29,742] Trial 19 finished with value: 0.7436203914527355 and parameters: {'num_leaves': 4}. Best is trial 11 with value: 0.7439639206248229.
# num_leaves, val_score: 0.745250:  65%|######5   | 13/20 [01:14<00:44,  6.36s/it]
# Did not meet early stopping. Best iteration is:
# [250]	valid_0's auc: 0.74362
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's auc: 0.741209
# num_leaves, val_score: 0.745250:  70%|#######   | 14/20 [01:17<00:33,  5.52s/it][I 2024-07-02 00:19:33,330] Trial 20 finished with value: 0.742379051519874 and parameters: {'num_leaves': 60}. Best is trial 11 with value: 0.7439639206248229.
# num_leaves, val_score: 0.745250:  70%|#######   | 14/20 [01:17<00:33,  5.52s/it]
# Early stopping, best iteration is:
# [66]	valid_0's auc: 0.742379
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's auc: 0.735725
# num_leaves, val_score: 0.745250:  75%|#######5  | 15/20 [01:25<00:30,  6.03s/it][I 2024-07-02 00:19:40,528] Trial 21 finished with value: 0.7383874143890944 and parameters: {'num_leaves': 129}. Best is trial 11 with value: 0.7439639206248229.
# num_leaves, val_score: 0.745250:  75%|#######5  | 15/20 [01:25<00:30,  6.03s/it]
# Early stopping, best iteration is:
# [49]	valid_0's auc: 0.738387
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's auc: 0.741326
# num_leaves, val_score: 0.745250:  80%|########  | 16/20 [01:28<00:20,  5.24s/it][I 2024-07-02 00:19:43,925] Trial 22 finished with value: 0.7424950827160643 and parameters: {'num_leaves': 41}. Best is trial 11 with value: 0.7439639206248229.
# num_leaves, val_score: 0.745250:  80%|########  | 16/20 [01:28<00:20,  5.24s/it]
# Early stopping, best iteration is:
# [68]	valid_0's auc: 0.742495
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's auc: 0.735209
# num_leaves, val_score: 0.745250:  85%|########5 | 17/20 [01:32<00:14,  4.89s/it][I 2024-07-02 00:19:48,012] Trial 23 finished with value: 0.7375288136772498 and parameters: {'num_leaves': 177}. Best is trial 11 with value: 0.7439639206248229.
# num_leaves, val_score: 0.745250:  85%|########5 | 17/20 [01:32<00:14,  4.89s/it]
# Early stopping, best iteration is:
# [35]	valid_0's auc: 0.737529
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's auc: 0.731774
# num_leaves, val_score: 0.745250:  90%|######### | 18/20 [01:40<00:11,  5.73s/it][I 2024-07-02 00:19:55,705] Trial 24 finished with value: 0.73372970450218 and parameters: {'num_leaves': 217}. Best is trial 11 with value: 0.7439639206248229.
# num_leaves, val_score: 0.745250:  90%|######### | 18/20 [01:40<00:11,  5.73s/it]
# Early stopping, best iteration is:
# [44]	valid_0's auc: 0.73373
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's auc: 0.735214
# num_leaves, val_score: 0.745250:  95%|#########5| 19/20 [01:44<00:05,  5.17s/it][I 2024-07-02 00:19:59,548] Trial 25 finished with value: 0.7394903940105456 and parameters: {'num_leaves': 123}. Best is trial 11 with value: 0.7439639206248229.
# num_leaves, val_score: 0.745250:  95%|#########5| 19/20 [01:44<00:05,  5.17s/it]
# Early stopping, best iteration is:
# [44]	valid_0's auc: 0.73949
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's auc: 0.744302
# num_leaves, val_score: 0.745250: 100%|##########| 20/20 [01:50<00:00,  5.60s/it][I 2024-07-02 00:20:06,175] Trial 26 finished with value: 0.7444532914602399 and parameters: {'num_leaves': 27}. Best is trial 26 with value: 0.7444532914602399.
# num_leaves, val_score: 0.745250: 100%|##########| 20/20 [01:50<00:00,  5.54s/it]
# Early stopping, best iteration is:
# [94]	valid_0's auc: 0.744453
# bagging, val_score: 0.745250:   0%|          | 0/10 [00:00<?, ?it/s]
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's auc: 0.738773
# bagging, val_score: 0.745250:  10%|#         | 1/10 [00:04<00:36,  4.04s/it][I 2024-07-02 00:20:10,230] Trial 27 finished with value: 0.739377823801672 and parameters: {'bagging_fraction': 0.5325355190899139, 'bagging_freq': 4}. Best is trial 27 with value: 0.739377823801672.
# bagging, val_score: 0.745250:  10%|#         | 1/10 [00:04<00:36,  4.04s/it]
# Early stopping, best iteration is:
# [87]	valid_0's auc: 0.739378
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's auc: 0.742612
# bagging, val_score: 0.745250:  20%|##        | 2/10 [00:07<00:31,  3.94s/it][I 2024-07-02 00:20:14,103] Trial 28 finished with value: 0.7436123634947012 and parameters: {'bagging_fraction': 0.9698725293478843, 'bagging_freq': 7}. Best is trial 28 with value: 0.7436123634947012.
# bagging, val_score: 0.745250:  20%|##        | 2/10 [00:07<00:31,  3.94s/it]
# Early stopping, best iteration is:
# [63]	valid_0's auc: 0.743612
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's auc: 0.738529
# bagging, val_score: 0.745250:  30%|###       | 3/10 [00:15<00:39,  5.65s/it][I 2024-07-02 00:20:21,789] Trial 29 finished with value: 0.7386728475047099 and parameters: {'bagging_fraction': 0.4150134068773815, 'bagging_freq': 1}. Best is trial 28 with value: 0.7436123634947012.
# bagging, val_score: 0.745250:  30%|###       | 3/10 [00:15<00:39,  5.65s/it]
# Early stopping, best iteration is:
# [92]	valid_0's auc: 0.738673
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's auc: 0.744342
# bagging, val_score: 0.745267:  40%|####      | 4/10 [00:22<00:37,  6.22s/it][I 2024-07-02 00:20:28,874] Trial 30 finished with value: 0.7452670219402076 and parameters: {'bagging_fraction': 0.873377977062142, 'bagging_freq': 1}. Best is trial 30 with value: 0.7452670219402076.
# bagging, val_score: 0.745267:  40%|####      | 4/10 [00:22<00:37,  6.22s/it]
# Early stopping, best iteration is:
# [71]	valid_0's auc: 0.745267
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's auc: 0.744147
# bagging, val_score: 0.745267:  50%|#####     | 5/10 [00:29<00:32,  6.47s/it][I 2024-07-02 00:20:35,807] Trial 31 finished with value: 0.7447752067026783 and parameters: {'bagging_fraction': 0.8974472268844133, 'bagging_freq': 1}. Best is trial 30 with value: 0.7452670219402076.
# bagging, val_score: 0.745267:  50%|#####     | 5/10 [00:29<00:32,  6.47s/it]
# Early stopping, best iteration is:
# [74]	valid_0's auc: 0.744775
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's auc: 0.743889
# bagging, val_score: 0.745267:  60%|######    | 6/10 [00:33<00:21,  5.45s/it][I 2024-07-02 00:20:39,255] Trial 32 finished with value: 0.7442601785849021 and parameters: {'bagging_fraction': 0.8894643060494907, 'bagging_freq': 1}. Best is trial 30 with value: 0.7452670219402076.
# bagging, val_score: 0.745267:  60%|######    | 6/10 [00:33<00:21,  5.45s/it]
# Early stopping, best iteration is:
# [61]	valid_0's auc: 0.74426
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's auc: 0.740267
# bagging, val_score: 0.745267:  70%|#######   | 7/10 [00:37<00:15,  5.05s/it][I 2024-07-02 00:20:43,488] Trial 33 finished with value: 0.7405999942069968 and parameters: {'bagging_fraction': 0.7813439318969435, 'bagging_freq': 2}. Best is trial 30 with value: 0.7452670219402076.
# bagging, val_score: 0.745267:  70%|#######   | 7/10 [00:37<00:15,  5.05s/it]
# Early stopping, best iteration is:
# [76]	valid_0's auc: 0.7406
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's auc: 0.742574
# bagging, val_score: 0.745267:  80%|########  | 8/10 [00:44<00:11,  5.67s/it][I 2024-07-02 00:20:50,485] Trial 34 finished with value: 0.7438445663699618 and parameters: {'bagging_fraction': 0.7735134821965449, 'bagging_freq': 3}. Best is trial 30 with value: 0.7452670219402076.
# bagging, val_score: 0.745267:  80%|########  | 8/10 [00:44<00:11,  5.67s/it]
# Early stopping, best iteration is:
# [56]	valid_0's auc: 0.743845
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's auc: 0.742504
# bagging, val_score: 0.745267:  90%|######### | 9/10 [00:48<00:05,  5.10s/it][I 2024-07-02 00:20:54,327] Trial 35 finished with value: 0.7428994307582617 and parameters: {'bagging_fraction': 0.8725258598584862, 'bagging_freq': 6}. Best is trial 30 with value: 0.7452670219402076.
# bagging, val_score: 0.745267:  90%|######### | 9/10 [00:48<00:05,  5.10s/it]
# Early stopping, best iteration is:
# [66]	valid_0's auc: 0.742899
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's auc: 0.743792
# bagging, val_score: 0.745267: 100%|##########| 10/10 [00:55<00:00,  5.75s/it][I 2024-07-02 00:21:01,522] Trial 36 finished with value: 0.7442541812430425 and parameters: {'bagging_fraction': 0.9894812978486717, 'bagging_freq': 1}. Best is trial 30 with value: 0.7452670219402076.
# bagging, val_score: 0.745267: 100%|##########| 10/10 [00:55<00:00,  5.53s/it]
# Early stopping, best iteration is:
# [91]	valid_0's auc: 0.744254
# feature_fraction_stage2, val_score: 0.745267:   0%|          | 0/3 [00:00<?, ?it/s]
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's auc: 0.743433
# feature_fraction_stage2, val_score: 0.745267:  33%|###3      | 1/3 [00:03<00:07,  3.64s/it][I 2024-07-02 00:21:05,183] Trial 37 finished with value: 0.7439621301066612 and parameters: {'feature_fraction': 0.48000000000000004}. Best is trial 37 with value: 0.7439621301066612.
# feature_fraction_stage2, val_score: 0.745267:  33%|###3      | 1/3 [00:03<00:07,  3.64s/it]
# Early stopping, best iteration is:
# [64]	valid_0's auc: 0.743962
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's auc: 0.743457
# feature_fraction_stage2, val_score: 0.745267:  67%|######6   | 2/3 [00:07<00:03,  3.93s/it][I 2024-07-02 00:21:09,311] Trial 38 finished with value: 0.7434573929984047 and parameters: {'feature_fraction': 0.44800000000000006}. Best is trial 37 with value: 0.7439621301066612.
# feature_fraction_stage2, val_score: 0.745267:  67%|######6   | 2/3 [00:07<00:03,  3.93s/it]
# [200]	valid_0's auc: 0.741903
# Early stopping, best iteration is:
# [100]	valid_0's auc: 0.743457
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's auc: 0.744342
# feature_fraction_stage2, val_score: 0.745267: 100%|##########| 3/3 [00:14<00:00,  5.25s/it][I 2024-07-02 00:21:16,126] Trial 39 finished with value: 0.7452670219402076 and parameters: {'feature_fraction': 0.41600000000000004}. Best is trial 39 with value: 0.7452670219402076.
# feature_fraction_stage2, val_score: 0.745267: 100%|##########| 3/3 [00:14<00:00,  4.86s/it]
# Early stopping, best iteration is:
# [71]	valid_0's auc: 0.745267
# regularization_factors, val_score: 0.745267:   0%|          | 0/20 [00:00<?, ?it/s]
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's auc: 0.744536
# regularization_factors, val_score: 0.745267:   5%|5         | 1/20 [00:03<01:10,  3.73s/it][I 2024-07-02 00:21:19,876] Trial 40 finished with value: 0.7452671190011064 and parameters: {'lambda_l1': 8.352827829341676e-06, 'lambda_l2': 2.6843755018106356e-06}. Best is trial 40 with value: 0.7452671190011064.
# regularization_factors, val_score: 0.745267:   5%|5         | 1/20 [00:03<01:10,  3.73s/it]
# Early stopping, best iteration is:
# [71]	valid_0's auc: 0.745267
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's auc: 0.744342
# regularization_factors, val_score: 0.745267:  10%|#         | 2/20 [00:07<01:06,  3.71s/it][I 2024-07-02 00:21:23,573] Trial 41 finished with value: 0.7452671496519166 and parameters: {'lambda_l1': 1.3085911206709773e-05, 'lambda_l2': 4.3980358938916035e-06}. Best is trial 41 with value: 0.7452671496519166.
# regularization_factors, val_score: 0.745267:  10%|#         | 2/20 [00:07<01:06,  3.71s/it]
# Early stopping, best iteration is:
# [71]	valid_0's auc: 0.745267
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's auc: 0.744525
# regularization_factors, val_score: 0.745267:  15%|#5        | 3/20 [00:14<01:27,  5.12s/it][I 2024-07-02 00:21:30,377] Trial 42 finished with value: 0.7452672211704737 and parameters: {'lambda_l1': 1.0394358420046087e-05, 'lambda_l2': 1.8616360951538022e-06}. Best is trial 42 with value: 0.7452672211704737.
# regularization_factors, val_score: 0.745267:  15%|#5        | 3/20 [00:14<01:27,  5.12s/it]
# Early stopping, best iteration is:
# [71]	valid_0's auc: 0.745267
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's auc: 0.744535
# regularization_factors, val_score: 0.745267:  20%|##        | 4/20 [00:17<01:12,  4.56s/it][I 2024-07-02 00:21:34,064] Trial 43 finished with value: 0.7452671138926381 and parameters: {'lambda_l1': 1.1307442815536003e-05, 'lambda_l2': 2.521490230763631e-06}. Best is trial 42 with value: 0.7452672211704737.
# regularization_factors, val_score: 0.745267:  20%|##        | 4/20 [00:17<01:12,  4.56s/it]
# Early stopping, best iteration is:
# [71]	valid_0's auc: 0.745267
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's auc: 0.744536
# regularization_factors, val_score: 0.745267:  25%|##5       | 5/20 [00:21<01:04,  4.29s/it][I 2024-07-02 00:21:37,891] Trial 44 finished with value: 0.7452671138926381 and parameters: {'lambda_l1': 8.369938024986294e-06, 'lambda_l2': 1.8622418729718386e-06}. Best is trial 42 with value: 0.7452672211704737.
# regularization_factors, val_score: 0.745267:  25%|##5       | 5/20 [00:21<01:04,  4.29s/it]
# Early stopping, best iteration is:
# [71]	valid_0's auc: 0.745267
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's auc: 0.744538
# regularization_factors, val_score: 0.745269:  30%|###       | 6/20 [00:28<01:12,  5.17s/it][I 2024-07-02 00:21:44,775] Trial 45 finished with value: 0.7452691521715153 and parameters: {'lambda_l1': 5.410933929411499e-06, 'lambda_l2': 1.9230800308663292e-06}. Best is trial 45 with value: 0.7452691521715153.
# regularization_factors, val_score: 0.745269:  30%|###       | 6/20 [00:28<01:12,  5.17s/it]
# Early stopping, best iteration is:
# [71]	valid_0's auc: 0.745269
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's auc: 0.744527
# regularization_factors, val_score: 0.745269:  35%|###5      | 7/20 [00:32<01:01,  4.69s/it][I 2024-07-02 00:21:48,476] Trial 46 finished with value: 0.745267210953537 and parameters: {'lambda_l1': 9.257432935518611e-06, 'lambda_l2': 1.8097908217919263e-06}. Best is trial 45 with value: 0.7452691521715153.
# regularization_factors, val_score: 0.745269:  35%|###5      | 7/20 [00:32<01:01,  4.69s/it]
# Early stopping, best iteration is:
# [71]	valid_0's auc: 0.745267
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's auc: 0.744525
# regularization_factors, val_score: 0.745269:  40%|####      | 8/20 [00:36<00:52,  4.38s/it][I 2024-07-02 00:21:52,178] Trial 47 finished with value: 0.7452672160620054 and parameters: {'lambda_l1': 8.55138209227268e-06, 'lambda_l2': 2.4845297589604005e-06}. Best is trial 45 with value: 0.7452691521715153.
# regularization_factors, val_score: 0.745269:  40%|####      | 8/20 [00:36<00:52,  4.38s/it]
# Early stopping, best iteration is:
# [71]	valid_0's auc: 0.745267
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's auc: 0.744536
# regularization_factors, val_score: 0.745269:  45%|####5     | 9/20 [00:42<00:56,  5.13s/it][I 2024-07-02 00:21:58,957] Trial 48 finished with value: 0.7452671138926381 and parameters: {'lambda_l1': 8.536477048477309e-06, 'lambda_l2': 1.8718407068054499e-06}. Best is trial 45 with value: 0.7452691521715153.
# regularization_factors, val_score: 0.745269:  45%|####5     | 9/20 [00:42<00:56,  5.13s/it]
# Early stopping, best iteration is:
# [71]	valid_0's auc: 0.745267
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's auc: 0.744537
# regularization_factors, val_score: 0.745269:  50%|#####     | 10/20 [00:46<00:46,  4.69s/it][I 2024-07-02 00:22:02,674] Trial 49 finished with value: 0.7452670168317391 and parameters: {'lambda_l1': 1.48103854888275e-05, 'lambda_l2': 2.240317628720835e-06}. Best is trial 45 with value: 0.7452691521715153.
# regularization_factors, val_score: 0.745269:  50%|#####     | 10/20 [00:46<00:46,  4.69s/it]
# Early stopping, best iteration is:
# [71]	valid_0's auc: 0.745267
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's auc: 0.744342
# regularization_factors, val_score: 0.745269:  55%|#####5    | 11/20 [00:50<00:41,  4.57s/it][I 2024-07-02 00:22:06,968] Trial 50 finished with value: 0.7452671394349799 and parameters: {'lambda_l1': 1.681112285601487e-08, 'lambda_l2': 1.7539960543926114e-06}. Best is trial 45 with value: 0.7452691521715153.
# regularization_factors, val_score: 0.745269:  55%|#####5    | 11/20 [00:50<00:41,  4.57s/it]
# Early stopping, best iteration is:
# [71]	valid_0's auc: 0.745267
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's auc: 0.744536
# regularization_factors, val_score: 0.745269:  60%|######    | 12/20 [00:56<00:40,  5.03s/it][I 2024-07-02 00:22:13,056] Trial 51 finished with value: 0.745266929987777 and parameters: {'lambda_l1': 1.205652627678629e-08, 'lambda_l2': 1.6913600105930476e-06}. Best is trial 45 with value: 0.7452691521715153.
# regularization_factors, val_score: 0.745269:  60%|######    | 12/20 [00:56<00:40,  5.03s/it]
# Early stopping, best iteration is:
# [71]	valid_0's auc: 0.745267
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's auc: 0.744537
# regularization_factors, val_score: 0.745269:  65%|######5   | 13/20 [01:00<00:32,  4.64s/it][I 2024-07-02 00:22:16,803] Trial 52 finished with value: 0.7452668635776882 and parameters: {'lambda_l1': 5.158189698765296e-08, 'lambda_l2': 9.286733874215163e-07}. Best is trial 45 with value: 0.7452691521715153.
# regularization_factors, val_score: 0.745269:  65%|######5   | 13/20 [01:00<00:32,  4.64s/it]
# Early stopping, best iteration is:
# [71]	valid_0's auc: 0.745267
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's auc: 0.743727
# regularization_factors, val_score: 0.745269:  70%|#######   | 14/20 [01:07<00:32,  5.38s/it][I 2024-07-02 00:22:23,883] Trial 53 finished with value: 0.7442812510169045 and parameters: {'lambda_l1': 0.004311493560215081, 'lambda_l2': 0.00041334559719519734}. Best is trial 45 with value: 0.7452691521715153.
# regularization_factors, val_score: 0.745269:  70%|#######   | 14/20 [01:07<00:32,  5.38s/it]
# Early stopping, best iteration is:
# [86]	valid_0's auc: 0.744281
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's auc: 0.746112
# [200]	valid_0's auc: 0.745502
# regularization_factors, val_score: 0.746524:  75%|#######5  | 15/20 [01:12<00:26,  5.29s/it][I 2024-07-02 00:22:28,981] Trial 54 finished with value: 0.7465240525336496 and parameters: {'lambda_l1': 5.128593600049496, 'lambda_l2': 1.4240199400397521e-08}. Best is trial 54 with value: 0.7465240525336496.
# regularization_factors, val_score: 0.746524:  75%|#######5  | 15/20 [01:12<00:26,  5.29s/it]
# Early stopping, best iteration is:
# [119]	valid_0's auc: 0.746524
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's auc: 0.744589
# [200]	valid_0's auc: 0.743427
# regularization_factors, val_score: 0.746524:  80%|########  | 16/20 [01:24<00:28,  7.12s/it][I 2024-07-02 00:22:40,335] Trial 55 finished with value: 0.7447976967346517 and parameters: {'lambda_l1': 0.8426179096230461, 'lambda_l2': 1.0043520181573096e-08}. Best is trial 54 with value: 0.7465240525336496.
# regularization_factors, val_score: 0.746524:  80%|########  | 16/20 [01:24<00:28,  7.12s/it]
# Early stopping, best iteration is:
# [150]	valid_0's auc: 0.744798
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's auc: 0.744536
# regularization_factors, val_score: 0.746524:  85%|########5 | 17/20 [01:27<00:18,  6.09s/it][I 2024-07-02 00:22:44,038] Trial 56 finished with value: 0.7452671905196635 and parameters: {'lambda_l1': 0.0002170646935504905, 'lambda_l2': 1.544956238184165e-08}. Best is trial 54 with value: 0.7465240525336496.
# regularization_factors, val_score: 0.746524:  85%|########5 | 17/20 [01:27<00:18,  6.09s/it]
# Early stopping, best iteration is:
# [71]	valid_0's auc: 0.745267
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's auc: 0.744527
# regularization_factors, val_score: 0.746524:  90%|######### | 18/20 [01:34<00:12,  6.30s/it][I 2024-07-02 00:22:50,822] Trial 57 finished with value: 0.7452675736547909 and parameters: {'lambda_l1': 0.0003880733174876314, 'lambda_l2': 1.6339823581518442e-08}. Best is trial 54 with value: 0.7465240525336496.
# regularization_factors, val_score: 0.746524:  90%|######### | 18/20 [01:34<00:12,  6.30s/it]
# Early stopping, best iteration is:
# [71]	valid_0's auc: 0.745268
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's auc: 0.746226
# [200]	valid_0's auc: 0.745141
# regularization_factors, val_score: 0.746561:  95%|#########5| 19/20 [01:39<00:05,  5.93s/it][I 2024-07-02 00:22:55,878] Trial 58 finished with value: 0.7465612830510879 and parameters: {'lambda_l1': 6.221227664763502, 'lambda_l2': 7.446671730419089e-08}. Best is trial 58 with value: 0.7465612830510879.
# regularization_factors, val_score: 0.746561:  95%|#########5| 19/20 [01:39<00:05,  5.93s/it]
# Early stopping, best iteration is:
# [117]	valid_0's auc: 0.746561
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's auc: 0.746911
# [200]	valid_0's auc: 0.746127
# Early stopping, best iteration is:
# [110]	valid_0's auc: 0.747016
# regularization_factors, val_score: 0.747016: 100%|##########| 20/20 [01:44<00:00,  5.69s/it][I 2024-07-02 00:23:01,007] Trial 59 finished with value: 0.7470164782331483 and parameters: {'lambda_l1': 7.869097420339159, 'lambda_l2': 8.687832834844037e-08}. Best is trial 59 with value: 0.7470164782331483.
# regularization_factors, val_score: 0.747016: 100%|##########| 20/20 [01:44<00:00,  5.24s/it]
# min_child_samples, val_score: 0.747016:   0%|          | 0/5 [00:00<?, ?it/s]
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's auc: 0.745849
# [200]	valid_0's auc: 0.744984
# min_child_samples, val_score: 0.747016:  20%|##        | 1/5 [00:08<00:35,  8.76s/it][I 2024-07-02 00:23:09,775] Trial 60 finished with value: 0.7460221097575883 and parameters: {'min_child_samples': 25}. Best is trial 60 with value: 0.7460221097575883.
# min_child_samples, val_score: 0.747016:  20%|##        | 1/5 [00:08<00:35,  8.76s/it]
# Did not meet early stopping. Best iteration is:
# [152]	valid_0's auc: 0.746022
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's auc: 0.745749
# [200]	valid_0's auc: 0.745336
# min_child_samples, val_score: 0.747016:  40%|####      | 2/5 [00:17<00:25,  8.60s/it][I 2024-07-02 00:23:18,262] Trial 61 finished with value: 0.7463147739101734 and parameters: {'min_child_samples': 50}. Best is trial 61 with value: 0.7463147739101734.
# min_child_samples, val_score: 0.747016:  40%|####      | 2/5 [00:17<00:25,  8.60s/it]
# Early stopping, best iteration is:
# [150]	valid_0's auc: 0.746315
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's auc: 0.74599
# [200]	valid_0's auc: 0.745534
# min_child_samples, val_score: 0.747016:  60%|######    | 3/5 [00:23<00:14,  7.41s/it][I 2024-07-02 00:23:24,267] Trial 62 finished with value: 0.7462934562716896 and parameters: {'min_child_samples': 5}. Best is trial 61 with value: 0.7463147739101734.
# min_child_samples, val_score: 0.747016:  60%|######    | 3/5 [00:23<00:14,  7.41s/it]
# Did not meet early stopping. Best iteration is:
# [152]	valid_0's auc: 0.746293
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's auc: 0.747787
# min_child_samples, val_score: 0.747948:  80%|########  | 4/5 [00:31<00:07,  7.86s/it][I 2024-07-02 00:23:32,801] Trial 63 finished with value: 0.7479477826667523 and parameters: {'min_child_samples': 100}. Best is trial 63 with value: 0.7479477826667523.
# min_child_samples, val_score: 0.747948:  80%|########  | 4/5 [00:31<00:07,  7.86s/it]
# Early stopping, best iteration is:
# [93]	valid_0's auc: 0.747948
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's auc: 0.746057
# min_child_samples, val_score: 0.747948: 100%|##########| 5/5 [00:36<00:00,  6.74s/it][I 2024-07-02 00:23:37,564] Trial 64 finished with value: 0.7461640076833408 and parameters: {'min_child_samples': 10}. Best is trial 63 with value: 0.7479477826667523.
# min_child_samples, val_score: 0.747948: 100%|##########| 5/5 [00:36<00:00,  7.31s/it]
# Early stopping, best iteration is:
# [97]	valid_0's auc: 0.746164

# %%
model_tune.params
# Out:
# {'objective': 'binary',
#  'metric': 'auc',
#  'verbosity': -1,
#  'feature_pre_filter': False,
#  'lambda_l1': 7.869097420339159,
#  'lambda_l2': 8.687832834844037e-08,
#  'num_leaves': 31,
#  'feature_fraction': 0.4,
#  'bagging_fraction': 0.873377977062142,
#  'bagging_freq': 1,
#  'min_child_samples': 100,
#  'num_iterations': 250}

# %%
from lightgbm import LGBMClassifier
import lightgbm as lgb

#lgb=LGBMClassifier(model_tune.params)

lgb=LGBMClassifier(
    objective='binary',
    metric='auc',
    verbosity=-1,
    feature_pre_filter= False,
    lambda_l1=2.0715144197588232e-06,
    lambda_l2=9.700220386223785,
    num_leaves=8,
    feature_fraction=0.45199999999999996,
    bagging_fraction=1.0,
    bagging_freq=0,
    min_child_samples=20,
    num_iterations=250)

# %%
models = [
    #("GBM", GradientBoostingClassifier(random_state=42)),
    #("Histogram Boosting", HistGradientBoostingClassifier(random_state=42)),
    #("SVM", SVC(probability=True, random_state=42)),
    #("XGBoost", XGBClassifier(random_state=42)),
    ("XGBoost", xgb),
    #("Catboost", CatBoostClassifier(verbose=0, random_state=42)),
    #("Regression", LogisticRegression(max_iter=600, random_state=42)),
    #("Random Forest", RandomForestClassifier(random_state=42)),
    #("K-Nearest", KNeighborsClassifier()),
    #("LGBMClassifier",LGBMClassifier(boosting_type='goss',random_state=42, verbose=-1))
    ("LGBMClassifier",lgb)
    #("MLPClassifier", MLPClassifier(hidden_layer_sizes=(100, 100, 10), random_state=42))
]
#ridge = Ridge(random_state=0)
for i, (name, model) in enumerate(models, 1):
    model.fit(X_train, y_train)
    train_pred = model.predict_proba(X_train)[:, 1]
    valid_pred = model.predict_proba(X_valid)[:, 1]
    print(f"Train Score: {roc_auc_score(y_train, train_pred)} - {name}")
    print(f"Valid Score: {roc_auc_score(y_valid, valid_pred)} - {name}")
# Out:
# Train Score: 0.8951014759450865 - XGBoost
# Valid Score: 0.7327511722785491 - XGBoost
# Train Score: 0.7744793333020908 - LGBMClassifier
# Valid Score: 0.7454609342908441 - LGBMClassifier

# %% [markdown]
# Croaa Validation

# %%
#    scores[(model_name, 'cross_val_score')] = cross_val_score(model, X_train, y_train, cv=5).mean()
#roc_auc_score_cv = cross_val_score(lgb, X, y, scoring="roc_auc", cv=5).mean()
#print(f"ROC_AUC_Score Train: {roc_auc_score_cv} - cross valivation")

# %%
#scores = cross_val_score(lightgbm, features, target, cv=3,scoring='neg_mean_squared_error')
#roc_auc_score_train = cross_val_score(lgb, X_train, y_train, cv=5).max()
#roc_auc_score_pred = cross_val_score(lgb, X_valid, y_valid, cv=5).max()

# %%
#voting_clf = VotingClassifier(estimators=models, voting='soft')
#voting_clf.fit(X_train, y_train)

#roc_auc_score_train = cross_val_score(voting_clf, X_train, y_train, cv=5).max()
#roc_auc_score_pred = cross_val_score(voting_clf, X_valid, y_valid, cv=5).max()

#print(f"ROC_AUC_Score Train: {roc_auc_score_train} - Voting")
#print(f"ROC_AUC_Score Pred: {roc_auc_score_pred} - Voting")

# %% [markdown]
# ## 4. 予測結果の作成
# 最後にテストデータに対して予測を行い、提出用のcsvファイルを作成します。

# %%
# テストデータに対する予測値の作成
#pred = xgb.predict_proba(X_test)[:, 1]
#pred= voting_clf.predict_proba(X_test)[:, 1]
#pred= voting_clf.predict_proba(X_test_std)[:, 1]
#pred = lgb.predict_proba(X_test)[:, 1]

# %%
#lr_pred   = lr.predict_proba(X_test)[:, 1]
lgb_pred  = lgb.predict_proba(X_test)[:, 1]
#xgb_pred = xgb.predict_proba(X_test)[:, 1]

#pred = (lr_pred + lgb_pred + xgb_pred)/3.0
pred = lgb_pred

# %%
# 予測結果を提出用のフォーマットに格納
sample_sub['TARGET'] = pred
sample_sub
# Out:
#        SK_ID_CURR    TARGET
# 0          171202  0.063646
# 1          171203  0.195255
# 2          171204  0.172607
# 3          171205  0.145937
# 4          171206  0.231424
# ...           ...       ...
# 61495      232697  0.195282
# 61496      232698  0.105536
# 61497      232699  0.135326
# 61498      232700  0.219197
# 61499      232701  0.126007
#
# [61500 rows x 2 columns]

# %%
from matplotlib import pyplot as plt
sample_sub['TARGET'].plot(kind='hist', bins=20, title='TARGET')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# 提出用のcsvファイルを作成
#sample_sub.to_csv('sub_competition2.csv',index=False)
if key_kaggle == True:
  sample_sub.to_csv('sub_competition2_kaggle.csv',index=False)
else:
  sample_sub.to_csv('sub_competition2.csv',index=False)

# %% [markdown]
# 以上で、Home Credit Default Riskコンペのチュートリアルは終了です。今回は、50種類ある特徴量のうち5種類しか使用していないので、まだまだ改善の余地があります。この後は、このnotebookやこれまでの教材を参考にして、さらなるスコアの向上を目指してください！

# %%
from google.colab import files
#files.download('sub_competition2.csv')
if key_kaggle == True:
  files.download('sub_competition2_kaggle.csv')
else:
  files.download('sub_competition2.csv')
